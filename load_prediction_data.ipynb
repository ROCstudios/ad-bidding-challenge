# %%
# !pip install pandas
import pandas as pd
# Out:
# Requirement already satisfied: pandas in ./env/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in ./env/lib/python3.11/site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./env/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./env/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./env/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in ./env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
data_to_predict_df = pd.read_csv('data/raw/data_to_predict.csv')
data_to_predict_df.head()
# Out:
#            sessionId       eDate channel country       os networkType  \
# 0   9705699729732200  2017-12-17     smt      BR      ios     unknown
# 1  12802690671750800  2017-12-17     smt      KH  android          3g
# 2  21347409150256300  2017-12-17     smt      ID      ios    not_wifi
# 3  23329125091887800  2017-12-17     inr      RU  android          3g
# 4  28266843791174100  2017-12-17     smt      DE  android        wifi
#
#   deviceType publisherCategory advertiserCategory    product  \
# 0     mobile               NaN          education  130000706
# 1     mobile     music & audio      entertainment  130167110
# 2     mobile               NaN             travel  130285027
# 3     mobile            social      music & audio     625569
# 4     mobile       photography                NaN  130356465
#
#                        subProduct   campaign           advPackage  \
# 0                       319881193  301604736  com.kawecki.onemind
# 1  com.fundevs.app.mediaconverter  300988528                  NaN
# 2           com.alcaydevs.idlfree  300228923       com.go-jek.ios
# 3                     drug.vokrug  301060338       com.p74.player
# 4        com.photo.editor.cartoon  301011313                  NaN
#
#          advMaturity   rate
# 0                 4+  0.010
# 1       low maturity  0.008
# 2                 4+  0.020
# 3  parental guidance  0.022
# 4           everyone  0.025

# %%
data_to_predict_df.describe(include='all')
# Out:
#            sessionId       eDate channel country       os networkType  \
# count   1.000000e+04       10000   10000   10000    10000       10000
# unique           NaN           1       5      46        2           4
# top              NaN  2017-12-17     mpb      RU  android          3g
# freq             NaN       10000    3812    2538     8024        6967
# mean    4.617623e+18         NaN     NaN     NaN      NaN         NaN
# std     2.659635e+18         NaN     NaN     NaN      NaN         NaN
# min     6.715025e+15         NaN     NaN     NaN      NaN         NaN
# 25%     2.326715e+18         NaN     NaN     NaN      NaN         NaN
# 50%     4.607486e+18         NaN     NaN     NaN      NaN         NaN
# 75%     6.925258e+18         NaN     NaN     NaN      NaN         NaN
# max     9.222836e+18         NaN     NaN     NaN      NaN         NaN
#
#        deviceType publisherCategory advertiserCategory       product  \
# count       10000              6646               9636  1.000000e+04
# unique          2                46                 33           NaN
# top        mobile            social      entertainment           NaN
# freq         9734              1618               3456           NaN
# mean          NaN               NaN                NaN  4.376681e+08
# std           NaN               NaN                NaN  6.079928e+08
# min           NaN               NaN                NaN  1.955700e+04
# 25%           NaN               NaN                NaN  6.255690e+05
# 50%           NaN               NaN                NaN  1.300101e+08
# 75%           NaN               NaN                NaN  8.068310e+08
# max           NaN               NaN                NaN  2.140191e+09
#
#          subProduct   campaign      advPackage   advMaturity          rate
# count          9928      10000            4196         10000  10000.000000
# unique          975        247              36            12           NaN
# top     drug.vokrug  300798390  com.p74.player  low maturity           NaN
# freq            959       1182            1865          4494           NaN
# mean            NaN        NaN             NaN           NaN      0.026102
# std             NaN        NaN             NaN           NaN      0.024923
# min             NaN        NaN             NaN           NaN      0.003000
# 25%             NaN        NaN             NaN           NaN      0.011000
# 50%             NaN        NaN             NaN           NaN      0.020000
# 75%             NaN        NaN             NaN           NaN      0.026000
# max             NaN        NaN             NaN           NaN      0.190000

# %%
prediction_df = data_to_predict_df.copy()
