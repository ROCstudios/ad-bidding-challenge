# %% [markdown]
# Summary of the features we're keeping to run this iteration.  Here are our splits:
# #
# | Feature Group | Features |
# |--------------|----------|
# | ~~Quantified Metrics~~  | ~~impressions, clicks, CTR (to create), AverageWinPrice (CPM)~~ |
# | Channel & Location    | channel, country, os, networkType, deviceType, CTR (to create), AverageWinPrice (CPM) |
# | ~~Quantified with Date & Profit~~        | ~~impressions, clicks, date, CTR (to create), AverageWinPrice (CPM), rate~~ |
# | Advertiser & Product     | advMaturity, publisherCategory, advertiserCategory, product, subProduct, campaign, AverageWinPrice (CPM) |

# %%
# !pip install numpy pandas matplotlib seaborn scikit-learn statsmodels openpyxl scipy
# Out:
# Requirement already satisfied: numpy in ./env/lib/python3.11/site-packages (2.1.2)
# Requirement already satisfied: pandas in ./env/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: matplotlib in ./env/lib/python3.11/site-packages (3.9.2)
# Requirement already satisfied: seaborn in ./env/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in ./env/lib/python3.11/site-packages (1.5.2)
# Requirement already satisfied: statsmodels in ./env/lib/python3.11/site-packages (0.14.4)
# Requirement already satisfied: openpyxl in ./env/lib/python3.11/site-packages (3.1.5)
# Requirement already satisfied: scipy in ./env/lib/python3.11/site-packages (1.14.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./env/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./env/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./env/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./env/lib/python3.11/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in ./env/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./env/lib/python3.11/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./env/lib/python3.11/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in ./env/lib/python3.11/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in ./env/lib/python3.11/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./env/lib/python3.11/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: joblib>=1.2.0 in ./env/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./env/lib/python3.11/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in ./env/lib/python3.11/site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: et-xmlfile in ./env/lib/python3.11/site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six in ./env/lib/python3.11/site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
#
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import numpy as np
from sklearn.preprocessing import StandardScaler
from scipy import stats
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ### Data Orientation

# %%
# split excel into multiple sheets
excel_file = 'data/raw/data.xlsx'
dir_name = 'data/raw'
xls = pd.ExcelFile(excel_file)

# load each sheet into a document
# Not overwrite
for sheet_name in xls.sheet_names:
    df = pd.read_excel(xls, sheet_name=sheet_name)
    csv_file = f"{dir_name}/{sheet_name.replace(' ', '_')}.csv"
    df.to_csv(csv_file, index=False)
    print(f"Saved sheet: {sheet_name}")
# Out:
# Saved sheet: historical data
# Saved sheet: data_to_predict

# %%
# let's take a look at the data
historical_df = pd.read_csv('data/raw/historical_data.csv')
historical_df.head()
# Out:
#    impressions  clicks       eDate channel country       os networkType  \
# 0            9       0  2017-12-09     inr      AU  android          3g
# 1            6       0  2017-12-09     inr      ES  android          3g
# 2           57       0  2017-12-09     inr      FR  android          3g
# 3           22       2  2017-12-09     inr      IT  android          3g
# 4            3       0  2017-12-09     inr      IT  android          3g
#
#   deviceType publisherCategory advertiserCategory   product  \
# 0     mobile       game_arcade      entertainment  600775.0
# 1     mobile       game_casual   game_educational  640029.0
# 2     mobile         game_word        game_action  618417.0
# 3     mobile    game_adventure      entertainment  631206.0
# 4     mobile       game_arcade      entertainment  632417.0
#
#                        subProduct   campaign advPackage   advMaturity  \
# 0                             NaN  301059092        NaN  low maturity
# 1          com.mohitdev.minebuild  300208158        NaN  low maturity
# 2    com.etermax.apalabrados.lite  300038580        NaN  low maturity
# 3              com.secg.robocraft  301068023        NaN  low maturity
# 4  com.craftpixelstudio.cubelands  300222537        NaN  low maturity
#
#    AverageWinPrice (CPM)      rate
# 0               1.404217  0.140000
# 1               0.575850  0.030000
# 2               0.052181  0.017333
# 3               0.265992  0.021000
# 4               0.676667  0.035000

# %%
# let's take a statistical summary of the data
historical_df.describe(include='all')
# Out:
#           impressions         clicks       eDate channel country       os  \
# count   304629.000000  304629.000000      304629  304629  304618   304629
# unique            NaN            NaN           8       5      53        2
# top               NaN            NaN  2017-12-11     mpb      ZA  android
# freq              NaN            NaN       40739  172588   48404   281007
# mean        88.306632       0.761815         NaN     NaN     NaN      NaN
# std       1193.871334      12.364807         NaN     NaN     NaN      NaN
# min          1.000000       0.000000         NaN     NaN     NaN      NaN
# 25%          2.000000       0.000000         NaN     NaN     NaN      NaN
# 50%          5.000000       0.000000         NaN     NaN     NaN      NaN
# 75%         21.000000       0.000000         NaN     NaN     NaN      NaN
# max     159617.000000    1495.000000         NaN     NaN     NaN      NaN
#
#        networkType deviceType publisherCategory advertiserCategory  \
# count       304629     304629            253895             299908
# unique           4          2                47                 38
# top             3g     mobile       game_puzzle      entertainment
# freq        204345     295987             31406             139492
# mean           NaN        NaN               NaN                NaN
# std            NaN        NaN               NaN                NaN
# min            NaN        NaN               NaN                NaN
# 25%            NaN        NaN               NaN                NaN
# 50%            NaN        NaN               NaN                NaN
# 75%            NaN        NaN               NaN                NaN
# max            NaN        NaN               NaN                NaN
#
#              product  subProduct   campaign      advPackage   advMaturity  \
# count   2.400300e+05      251823     302951           76388        304628
# unique           NaN         875        370              65            12
# top              NaN  1075264954  300798390  com.p74.player  low maturity
# freq             NaN        2779       7335           10025        187226
# mean    6.370810e+08         NaN        NaN             NaN           NaN
# std     6.842803e+08         NaN        NaN             NaN           NaN
# min     1.627600e+04         NaN        NaN             NaN           NaN
# 25%     2.872324e+06         NaN        NaN             NaN           NaN
# 50%     3.058059e+08         NaN        NaN             NaN           NaN
# 75%     1.219066e+09         NaN        NaN             NaN           NaN
# max     2.144018e+09         NaN        NaN             NaN           NaN
#
#         AverageWinPrice (CPM)           rate
# count           304629.000000  304629.000000
# unique                    NaN            NaN
# top                       NaN            NaN
# freq                      NaN            NaN
# mean                 0.207046       0.027231
# std                  0.332051       0.027564
# min                  0.007190       0.003000
# 25%                  0.050000       0.011000
# 50%                  0.105240       0.020000
# 75%                  0.207143       0.030000
# max                 12.641820       0.190000

# %%
data_to_predict_df = pd.read_csv('data/raw/data_to_predict.csv')
data_to_predict_df.head()
# Out:
#            sessionId       eDate channel country       os networkType  \
# 0   9705699729732200  2017-12-17     smt      BR      ios     unknown
# 1  12802690671750800  2017-12-17     smt      KH  android          3g
# 2  21347409150256300  2017-12-17     smt      ID      ios    not_wifi
# 3  23329125091887800  2017-12-17     inr      RU  android          3g
# 4  28266843791174100  2017-12-17     smt      DE  android        wifi
#
#   deviceType publisherCategory advertiserCategory    product  \
# 0     mobile               NaN          education  130000706
# 1     mobile     music & audio      entertainment  130167110
# 2     mobile               NaN             travel  130285027
# 3     mobile            social      music & audio     625569
# 4     mobile       photography                NaN  130356465
#
#                        subProduct   campaign           advPackage  \
# 0                       319881193  301604736  com.kawecki.onemind
# 1  com.fundevs.app.mediaconverter  300988528                  NaN
# 2           com.alcaydevs.idlfree  300228923       com.go-jek.ios
# 3                     drug.vokrug  301060338       com.p74.player
# 4        com.photo.editor.cartoon  301011313                  NaN
#
#          advMaturity   rate
# 0                 4+  0.010
# 1       low maturity  0.008
# 2                 4+  0.020
# 3  parental guidance  0.022
# 4           everyone  0.025

# %%
# dataframe dimensions
print(f"This dataframe has {historical_df.shape[0]} rows and {historical_df.shape[1]} columns.")
historical_df.info()
# Out:
# This dataframe has 304629 rows and 17 columns.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304629 entries, 0 to 304628
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   impressions            304629 non-null  int64
#  1   clicks                 304629 non-null  int64
#  2   eDate                  304629 non-null  object
#  3   channel                304629 non-null  object
#  4   country                304618 non-null  object
#  5   os                     304629 non-null  object
#  6   networkType            304629 non-null  object
#  7   deviceType             304629 non-null  object
#  8   publisherCategory      253895 non-null  object
#  9   advertiserCategory     299908 non-null  object
#  10  product                240030 non-null  float64
#  11  subProduct             251823 non-null  object
#  12  campaign               302951 non-null  object
#  13  advPackage             76388 non-null   object
#  14  advMaturity            304628 non-null  object
#  15  AverageWinPrice (CPM)  304629 non-null  float64
#  16  rate                   304629 non-null  float64
# dtypes: float64(3), int64(2), object(12)
# memory usage: 39.5+ MB

# %%
# let's look at the distribution of our categorical variables
for column in historical_df.columns:
    if historical_df[column].dtype == 'object':
        print(f"Distribution of {column}:")
        print(historical_df[column].value_counts())
        print("\n")
# Out:
# Distribution of eDate:
# eDate
# 2017-12-11    40739
# 2017-12-13    39743
# 2017-12-16    39000
# 2017-12-12    38743
# 2017-12-14    38546
# 2017-12-09    37791
# 2017-12-10    36090
# 2017-12-15    33977
# Name: count, dtype: int64
#
#
# Distribution of channel:
# channel
# mpb    172588
# inr     72340
# smt     49929
# nxg      9495
# rub       277
# Name: count, dtype: int64
#
#
# Distribution of country:
# country
# ZA    48404
# JP    46055
# ES    27456
# RU    26017
# PL    17768
# FR    11087
# IT     9515
# BR     9087
# MM     8869
# AE     8582
# US     5925
# AU     5829
# KR     5520
# PA     4926
# EG     4125
# TN     4115
# ID     3853
# PT     3754
# OM     3407
# CL     3230
# BH     2932
# DE     2930
# DZ     2799
# GB     2793
# MA     2558
# NG     2534
# HK     2471
# KH     2435
# VN     2382
# KW     2341
# TR     2064
# NO     1942
# MX     1675
# RS     1665
# NL     1586
# IN     1536
# SN     1271
# DO     1245
# SG     1121
# PY      962
# TH      916
# HN      842
# CA      738
# MY      590
# PH      577
# AT      551
# PK      512
# HU      415
# QA      247
# TW      205
# CR      130
# SA      116
# CI       13
# Name: count, dtype: int64
#
#
# Distribution of os:
# os
# android    281007
# ios         23622
# Name: count, dtype: int64
#
#
# Distribution of networkType:
# networkType
# 3g          204345
# wifi         56356
# not_wifi     32926
# unknown      11002
# Name: count, dtype: int64
#
#
# Distribution of deviceType:
# deviceType
# mobile    295987
# tablet      8642
# Name: count, dtype: int64
#
#
# Distribution of publisherCategory:
# publisherCategory
# game_puzzle                31406
# game_casual                22876
# entertainment              16693
# game_action                15188
# social                     13281
# tools                      12513
# game_simulation            11629
# game_arcade                 9939
# photography                 9722
# game_board                  9520
# game_role_playing           8151
# game_adventure              8078
# music & audio               7671
# game_word                   7232
# game_sports                 5930
# productivity                5044
# books & reference           4845
# game_educational            4572
# video players & editors     4478
# game_trivia                 4465
# sports                      4192
# dating                      4009
# game_racing                 3791
# game_card                   3553
# news & magazines            3207
# game_music                  2926
# health & fitness            2857
# weather                     2343
# communication               2107
# personalization             1856
# lifestyle                   1855
# shopping                    1422
# education                   1192
# travel & local               941
# medical                      843
# business                     763
# comics                       653
# maps & navigation            539
# games                        370
# finance                      361
# game_casino                  269
# auto & vehicles              173
# music                        127
# libraries & demo             125
# house & home                  73
# book                          60
# social networking             55
# Name: count, dtype: int64
#
#
# Distribution of advertiserCategory:
# advertiserCategory
# entertainment              139492
# game_arcade                 23336
# game_casual                 17917
# shopping                    16003
# game_action                 14345
# games                       12592
# music & audio               11947
# travel & local              10167
# game_role_playing            8241
# game_music                   5185
# game_educational             4476
# books & reference            4296
# personalization              3683
# game_adventure               3567
# news & magazines             3456
# lifestyle                    2507
# food & drink                 2358
# game_simulation              1886
# social networking            1701
# travel                       1590
# finance                      1521
# social                       1506
# education                    1461
# photo & video                1413
# dating                        704
# tools                         671
# game_board                    652
# video players & editors       652
# utilities                     538
# family_brain_games            530
# auto & vehicles               442
# game_puzzle                   382
# sports                        211
# books                         194
# media & video                 142
# photography                    79
# events                         33
# game_strategy                  32
# Name: count, dtype: int64
#
#
# Distribution of subProduct:
# subProduct
# 1075264954                         2779
# com.surpax.ledflashlight.panel     2191
# com.outfit7.mytalkingangelafree    2140
# com.outfit7.mytalkingtomfree       1960
# devian.tubemate.home               1932
#                                    ...
# tk.mediacreator.khmersupermusic       7
# com.animatures.cartoonyourself        7
# com.wBitcoinfree_5424463              6
# 616583799                             5
# com.afksoft.WordShakerLite            3
# Name: count, Length: 875, dtype: int64
#
#
# Distribution of campaign:
# campaign
# 300798390    7335
# 301569414    6088
# 300659871    4838
# 301044597    4562
# 301104885    4296
#              ...
# 301103437       8
# 301011772       7
# 301227420       6
# 300997859       4
# 300063871       3
# Name: count, Length: 370, dtype: int64
#
#
# Distribution of advPackage:
# advPackage
# com.p74.player                        10025
# com.stairs.destinychild                5673
# jp.co.bandainamcoent.BNEI0242          5069
# jp.co.yahoo.android.yshopping          4838
# jp.co.bandainamcoonline.grasma         4436
#                                       ...
# jp.co.a-tm.derbyimpact                   87
# com.ss.iphone.ugc.Ame                    61
# jp.colopl.tennis                         52
# com.hulu.plus                            23
# com.ladbrokes.sportsbook.iphone.uk       18
# Name: count, Length: 65, dtype: int64
#
#
# Distribution of advMaturity:
# advMaturity
# low maturity         187226
# everyone              33154
# pegi 3                24929
# parental guidance     15207
# pegi 12               14081
# 4+                     7799
# 12+                    7747
# 9+                     5232
# adults only            3335
# 17+                    2844
# high maturity          1813
# pegi 7                 1261
# Name: count, dtype: int64

# %% [markdown]
# ### Visualizing our dataframes and eventual modeling
#
# Predict CTR first, then use these predictions to predict CPM. This approach lets you refine the CTR predictions independently, which may improve the quality of CPM predictions.
#
# If you’re not satisfied with the results, you could then try a multi-target model to see if simultaneous predictions capture hidden correlations better.

# %%
#create our CTR feature
historical_df['CTR'] = historical_df['clicks'] / historical_df['impressions']
print(f"The mean CTR is: {historical_df['CTR'].mean():.4%}")
# Out:
# The mean CTR is: 1.5350%

# %%
combined_metrics_cols = ['channel', 'country', 'os', 'networkType', 'deviceType', 'advMaturity', 'publisherCategory', 'advertiserCategory', 'product', 'subProduct', 'campaign', 'CTR', 'AverageWinPrice (CPM)']

# %%
# wow that's looking alike a mess
unique_counts = historical_df[combined_metrics_cols].nunique()
print("Number of unique values per column:")
print(unique_counts)
# Out:
# Number of unique values per column:
# channel                       5
# country                      53
# os                            2
# networkType                   4
# deviceType                    2
# advMaturity                  12
# publisherCategory            47
# advertiserCategory           38
# product                    1104
# subProduct                  875
# campaign                    370
# CTR                        6642
# AverageWinPrice (CPM)    116825
# dtype: int64

# %% [markdown]
# ### Preprocessing & EDA
#
# Removing outliers, missing values, etc.
#
# Encoding of categorical variables to numbers
#
# Declaring our target features.

# %%
# create our new dataframe with our features from channel_metrics_cols
historical_eda_df = historical_df[combined_metrics_cols]
historical_eda_df.head()
# Out:
#   channel country       os networkType deviceType   advMaturity  \
# 0     inr      AU  android          3g     mobile  low maturity
# 1     inr      ES  android          3g     mobile  low maturity
# 2     inr      FR  android          3g     mobile  low maturity
# 3     inr      IT  android          3g     mobile  low maturity
# 4     inr      IT  android          3g     mobile  low maturity
#
#   publisherCategory advertiserCategory   product  \
# 0       game_arcade      entertainment  600775.0
# 1       game_casual   game_educational  640029.0
# 2         game_word        game_action  618417.0
# 3    game_adventure      entertainment  631206.0
# 4       game_arcade      entertainment  632417.0
#
#                        subProduct   campaign       CTR  AverageWinPrice (CPM)
# 0                             NaN  301059092  0.000000               1.404217
# 1          com.mohitdev.minebuild  300208158  0.000000               0.575850
# 2    com.etermax.apalabrados.lite  300038580  0.000000               0.052181
# 3              com.secg.robocraft  301068023  0.090909               0.265992
# 4  com.craftpixelstudio.cubelands  300222537  0.000000               0.676667

# %%
# Print data types of each column
print("\nData types of each column:")
historical_eda_df.dtypes
# Out:
# Data types of each column:
# channel                   object
# country                   object
# os                        object
# networkType               object
# deviceType                object
# advMaturity               object
# publisherCategory         object
# advertiserCategory        object
# product                  float64
# subProduct                object
# campaign                  object
# CTR                      float64
# AverageWinPrice (CPM)    float64
# dtype: object

# %%
# missing values summary
def missing_values_summary(df): 
    return pd.DataFrame(
        zip(
            df.columns,
            df.isna().any(),
            (df.isna().sum() / df.shape[0] * 100).round(2),
            df.dtypes,
            df.apply(lambda x: x.sample(n=1).iloc[0] if len(x) > 0 else None)),
        columns=['Column', 'Has Missing Values', '% Missing Values', 'Feature Type', 'Sample Value']
    )

missing_values_summary(historical_eda_df)
# Out:
#                    Column  Has Missing Values  % Missing Values Feature Type  \
# 0                 channel               False              0.00       object
# 1                 country                True              0.00       object
# 2                      os               False              0.00       object
# 3             networkType               False              0.00       object
# 4              deviceType               False              0.00       object
# 5             advMaturity                True              0.00       object
# 6       publisherCategory                True             16.65       object
# 7      advertiserCategory                True              1.55       object
# 8                 product                True             21.21      float64
# 9              subProduct                True             17.33       object
# 10               campaign                True              0.55       object
# 11                    CTR               False              0.00      float64
# 12  AverageWinPrice (CPM)               False              0.00      float64
#
#     Sample Value
# 0            inr
# 1             NG
# 2            ios
# 3             3g
# 4         mobile
# 5   low maturity
# 6            NaN
# 7    game_casual
# 8   1845233409.0
# 9            NaN
# 10     300580725
# 11      0.013333
# 12       0.40667

# %%
# First, let's see the original row count
print(f"Original row count: {len(historical_eda_df)}")

#  Fill missing values strategically
strategic_df = historical_eda_df.copy()

strategic_df = strategic_df.dropna(subset=['channel'])
strategic_df = strategic_df.dropna(subset=['country'])
strategic_df = strategic_df.dropna(subset=['os'])
strategic_df = strategic_df.dropna(subset=['networkType'])
strategic_df = strategic_df.dropna(subset=['deviceType'])
strategic_df = strategic_df.dropna(subset=['advMaturity'])

strategic_df['publisherCategory'] = strategic_df['publisherCategory'].fillna('UNKNOWN')
strategic_df['advertiserCategory'] = strategic_df['advertiserCategory'].fillna('UNKNOWN')

strategic_df['product'] = strategic_df['product'].fillna('UNKNOWN')
strategic_df['subProduct'] = strategic_df['subProduct'].fillna('UNKNOWN')
strategic_df['campaign'] = strategic_df['campaign'].fillna('UNKNOWN')

print(f"Row count after strategic filling: {len(strategic_df)}")
missing_values_summary(strategic_df)
# Out:
# Original row count: 304629
# Row count after strategic filling: 304617
#                    Column  Has Missing Values  % Missing Values Feature Type  \
# 0                 channel               False               0.0       object
# 1                 country               False               0.0       object
# 2                      os               False               0.0       object
# 3             networkType               False               0.0       object
# 4              deviceType               False               0.0       object
# 5             advMaturity               False               0.0       object
# 6       publisherCategory               False               0.0       object
# 7      advertiserCategory               False               0.0       object
# 8                 product               False               0.0       object
# 9              subProduct               False               0.0       object
# 10               campaign               False               0.0       object
# 11                    CTR               False               0.0      float64
# 12  AverageWinPrice (CPM)               False               0.0      float64
#
#          Sample Value
# 0                 mpb
# 1                  KR
# 2             android
# 3                wifi
# 4              mobile
# 5   parental guidance
# 6        productivity
# 7               games
# 8            600775.0
# 9       com.hideitpro
# 10          301095560
# 11                0.0
# 12               0.17

# %%
# let's take our UUIDs and format uniformly
print("Product samples:")
print(strategic_df['product'].head(10))
print("\nSubProduct samples:")
print(strategic_df['subProduct'].head(10))
print("\nCampaign samples:")
print(strategic_df['campaign'].head(10))

# convert each of these features to strings
strategic_df['product'] = strategic_df['product'].astype(str)
strategic_df['subProduct'] = strategic_df['subProduct'].astype(str)
strategic_df['campaign'] = strategic_df['campaign'].astype(str)

def analyze_id_format(series, column_name):
    print(f"\n{column_name} Analysis:")
    print(f"Total unique values: {series.nunique()}")
    print(f"Data type: {series.dtype}")
    
    # Check for different formats
    print("\nSample formats:")
    print(series.value_counts().head())
    
    # Check for potential issues
    print("\nPotential issues:")
    print("NaN values:", series.isna().sum())
    print("Empty strings:", (series == '').sum())
    print("Decimal points:", series.astype(str).str.contains('\.').sum())
    print("Non-numeric:", series.astype(str).str.contains('[^0-9\.]').sum())

analyze_id_format(strategic_df['product'], 'Product')
analyze_id_format(strategic_df['subProduct'], 'SubProduct')
analyze_id_format(strategic_df['campaign'], 'Campaign')
# Out:
# Product samples:
# 0    600775.0
# 1    640029.0
# 2    618417.0
# 3    631206.0
# 4    632417.0
# 5    600775.0
# 6    605078.0
# 7     UNKNOWN
# 8    608474.0
# 9    602318.0
# Name: product, dtype: object
#
# SubProduct samples:
# 0                           UNKNOWN
# 1            com.mohitdev.minebuild
# 2      com.etermax.apalabrados.lite
# 3                com.secg.robocraft
# 4    com.craftpixelstudio.cubelands
# 5                           UNKNOWN
# 6                   com.mmo.android
# 7                           UNKNOWN
# 8          air.hockey.sweetgamesbox
# 9             com.devexpert.weather
# Name: subProduct, dtype: object
#
# Campaign samples:
# 0    301059092
# 1    300208158
# 2    300038580
# 3    301068023
# 4    300222537
# 5    300222537
# 6    301068023
# 7    300222537
# 8    301044597
# 9    300659871
# Name: campaign, dtype: object
#
# Product Analysis:
# Total unique values: 1105
# Data type: object
#
# Sample formats:
# product
# UNKNOWN        64591
# 600775.0        5500
# 130006611.0     3563
# 630535.0        2205
# 65850401.0      1597
# Name: count, dtype: int64
#
# Potential issues:
# NaN values: 0
# Empty strings: 0
# Decimal points: 240026
# Non-numeric: 64591
#
# SubProduct Analysis:
# Total unique values: 876
# Data type: object
#
# Sample formats:
# subProduct
# UNKNOWN                            52798
# 1075264954                          2779
# com.surpax.ledflashlight.panel      2190
# com.outfit7.mytalkingangelafree     2140
# com.outfit7.mytalkingtomfree        1960
# Name: count, dtype: int64
#
# Potential issues:
# NaN values: 0
# Empty strings: 0
# Decimal points: 231300
# Non-numeric: 284166
#
# Campaign Analysis:
# Total unique values: 371
# Data type: object
#
# Sample formats:
# campaign
# 300798390    7335
# 301569414    6087
# 300659871    4838
# 301044597    4561
# 301104885    4294
# Name: count, dtype: int64
#
# Potential issues:
# NaN values: 0
# Empty strings: 0
# Decimal points: 0
# Non-numeric: 5312

# %%
# Clean and standardize format
def standardize_id(series):
    # Convert to string
    series = series.astype(str)
    
    # Remove decimal points (if any)
    series = series.str.replace('.0', '', regex=False)
    
    # Replace NaN/empty with placeholder
    series = series.replace(['nan', 'NaN', '', 'None'], 'UNKNOWN')
    
    return series

# Apply standardization
strategic_df['product_clean'] = standardize_id(strategic_df['product'])
strategic_df['subProduct_clean'] = standardize_id(strategic_df['subProduct'])
strategic_df['campaign_clean'] = standardize_id(strategic_df['campaign'])

# Verify results
print("\nAfter cleaning:")
print("\nProduct samples:")
print(strategic_df['product_clean'].head())
print("\nSubProduct samples:")
print(strategic_df['subProduct_clean'].head())
print("\nCampaign samples:")
print(strategic_df['campaign_clean'].head())

#drop the original product, subProduct, and campaign columns
strategic_df = strategic_df.drop(columns=['product', 'subProduct', 'campaign'])
combined_metrics_cols = ['channel', 'country', 'os', 'networkType', 'deviceType', 'advMaturity', 'publisherCategory', 'advertiserCategory', 'product_clean', 'subProduct_clean', 'campaign_clean', 'CTR', 'AverageWinPrice (CPM)']
# Out:
# After cleaning:
#
# Product samples:
# 0    600775
# 1    640029
# 2    618417
# 3    631206
# 4    632417
# Name: product_clean, dtype: object
#
# SubProduct samples:
# 0                           UNKNOWN
# 1            com.mohitdev.minebuild
# 2      com.etermax.apalabrados.lite
# 3                com.secg.robocraft
# 4    com.craftpixelstudio.cubelands
# Name: subProduct_clean, dtype: object
#
# Campaign samples:
# 0    301059092
# 1    300208158
# 2    300038580
# 3    301068023
# 4    300222537
# Name: campaign_clean, dtype: object

# %%
# here is where we will pass in our different tiny-dataframes into our created methods for visualization
strategic_df.describe().T
# Out:
#                           count      mean       std      min   25%      50%  \
# CTR                    304617.0  0.015348  0.089512  0.00000  0.00  0.00000
# AverageWinPrice (CPM)  304617.0  0.207051  0.332056  0.00719  0.05  0.10524
#
#                             75%       max
# CTR                    0.000000   1.00000
# AverageWinPrice (CPM)  0.207143  12.64182

# %%
# Check for any obvious errors or outliers
for col in strategic_df.columns:
    print(f"\n{col} - sample values:")
    print(strategic_df[col].value_counts().head())
# Out:
# channel - sample values:
# channel
# mpb    172587
# inr     72340
# smt     49929
# nxg      9495
# rub       266
# Name: count, dtype: int64
#
# country - sample values:
# country
# ZA    48404
# JP    46055
# ES    27456
# RU    26017
# PL    17768
# Name: count, dtype: int64
#
# os - sample values:
# os
# android    280995
# ios         23622
# Name: count, dtype: int64
#
# networkType - sample values:
# networkType
# 3g          204344
# wifi         56354
# not_wifi     32924
# unknown      10995
# Name: count, dtype: int64
#
# deviceType - sample values:
# deviceType
# mobile    295975
# tablet      8642
# Name: count, dtype: int64
#
# advMaturity - sample values:
# advMaturity
# low maturity         187224
# everyone              33151
# pegi 3                24925
# parental guidance     15207
# pegi 12               14079
# Name: count, dtype: int64
#
# publisherCategory - sample values:
# publisherCategory
# UNKNOWN          50726
# game_puzzle      31406
# game_casual      22876
# entertainment    16693
# game_action      15188
# Name: count, dtype: int64
#
# advertiserCategory - sample values:
# advertiserCategory
# entertainment    139489
# game_arcade       23336
# game_casual       17917
# shopping          16001
# game_action       14345
# Name: count, dtype: int64
#
# CTR - sample values:
# CTR
# 0.000000    261653
# 1.000000      1841
# 0.500000      1046
# 0.333333       903
# 0.250000       842
# Name: count, dtype: int64
#
# AverageWinPrice (CPM) - sample values:
# AverageWinPrice (CPM)
# 0.04    12449
# 0.02    12255
# 0.09     8187
# 0.06     6227
# 0.10     5221
# Name: count, dtype: int64
#
# product_clean - sample values:
# product_clean
# UNKNOWN      64591
# 600775        5500
# 130006611     3563
# 630535        2205
# 65850401      1597
# Name: count, dtype: int64
#
# subProduct_clean - sample values:
# subProduct_clean
# UNKNOWN                            52798
# 1075264954                          2779
# com.surpax.ledflashlight.panel      2190
# com.outfit7.mytalkingangelafree     2140
# com.outfit7.mytalkingtomfree        1960
# Name: count, dtype: int64
#
# campaign_clean - sample values:
# campaign_clean
# 300798390    7335
# 301569414    6087
# 300659871    4838
# 301044597    4561
# 301104885    4294
# Name: count, dtype: int64

# %% [markdown]
# ### Seems like we have all of our data cleaned and ready for encoding and modeling

# %%
# Categorical Encoding
# Define a function to perform target encoding
def target_encode(df, target_col, category_col):
    mean_target = df.groupby(category_col)[target_col].mean()
    df[category_col + '_encoded'] = df[category_col].map(mean_target)
    return df

# %%
# Create a copy of the dataframe for CTR analysis
ctr_df = strategic_df.copy()
ctr_df = ctr_df.dropna(subset=strategic_df.columns)

for col in ctr_df.columns:
    train_data = target_encode(ctr_df, 'CTR', col)
    train_data = target_encode(ctr_df, 'AverageWinPrice (CPM)', col)  

# drop the original advertiser & product columns
X = train_data.drop(columns=combined_metrics_cols)
X = X.drop(columns=['CTR_encoded', 'AverageWinPrice (CPM)_encoded'])

y = train_data[['CTR_encoded', 'AverageWinPrice (CPM)_encoded']]

X.head()
# Out:
#    channel_encoded  country_encoded  os_encoded  networkType_encoded  \
# 0         0.257611         0.480528    0.216265             0.216783
# 1         0.257611         0.186420    0.216265             0.216783
# 2         0.257611         0.215790    0.216265             0.216783
# 3         0.257611         0.222408    0.216265             0.216783
# 4         0.257611         0.222408    0.216265             0.216783
#
#    deviceType_encoded  advMaturity_encoded  publisherCategory_encoded  \
# 0            0.207289             0.199133                   0.226699
# 1            0.207289             0.199133                   0.366860
# 2            0.207289             0.199133                   0.170109
# 3            0.207289             0.199133                   0.344861
# 4            0.207289             0.199133                   0.226699
#
#    advertiserCategory_encoded  product_clean_encoded  \
# 0                    0.223634               0.183729
# 1                    0.160507               0.491654
# 2                    0.142369               0.058438
# 3                    0.223634               0.352754
# 4                    0.223634               0.283370
#
#    subProduct_clean_encoded  campaign_clean_encoded
# 0                  0.181598                0.643322
# 1                  0.335028                0.184772
# 2                  0.073384                0.271474
# 3                  0.236854                0.176314
# 4                  0.502179                0.279278

# %%
# Create a DataFrame that includes both features and targets
correlation_df = X.copy()
correlation_df['CTR'] = y['CTR_encoded']
correlation_df['CPM'] = y['AverageWinPrice (CPM)_encoded']

# Create correlation matrix
correlation_matrix = correlation_df.corr()

# Create a larger figure for better readability
plt.figure(figsize=(15, 10))

# Create heatmap with modified parameters
sns.heatmap(correlation_matrix, 
            annot=True,           
            cmap='coolwarm',      
            center=0,             
            fmt='.2f',
            square=True)          # Make cells square for better visualization

plt.title('Feature Correlation Matrix (Including CTR and CPM)')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# Optionally, print the correlations with CTR and CPM specifically
print("\nCorrelations with CTR:")
print(correlation_matrix['CTR'].sort_values(ascending=False))
print("\nCorrelations with CPM:")
print(correlation_matrix['CPM'].sort_values(ascending=False))
# Out:
# Correlations with CTR:
# CTR                           1.000000
# CPM                           0.210734
# product_clean_encoded         0.206595
# subProduct_clean_encoded      0.200123
# publisherCategory_encoded     0.124375
# campaign_clean_encoded        0.049597
# os_encoded                    0.042309
# channel_encoded               0.038864
# advertiserCategory_encoded    0.036470
# networkType_encoded           0.024404
# advMaturity_encoded           0.018803
# country_encoded               0.001185
# deviceType_encoded            0.000679
# Name: CTR, dtype: float64
#
# Correlations with CPM:
# CPM                           1.000000
# product_clean_encoded         0.595801
# subProduct_clean_encoded      0.557526
# campaign_clean_encoded        0.485176
# country_encoded               0.357641
# publisherCategory_encoded     0.288183
# advMaturity_encoded           0.244895
# CTR                           0.210734
# advertiserCategory_encoded    0.177393
# channel_encoded               0.096394
# os_encoded                    0.095706
# networkType_encoded           0.077256
# deviceType_encoded            0.004194
# Name: CPM, dtype: float64

# %%
# !pip install xgboost
from xgboost import XGBRegressor
# Out:
# Requirement already satisfied: xgboost in ./env/lib/python3.11/site-packages (2.1.2)
# Requirement already satisfied: numpy in ./env/lib/python3.11/site-packages (from xgboost) (2.1.2)
# Requirement already satisfied: scipy in ./env/lib/python3.11/site-packages (from xgboost) (1.14.1)
#
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
# Stratified samplign for cross validation
from sklearn.multioutput import MultiOutputRegressor

# Create bins for CTR (our target variable) since StratifiedKFold requires categorical labels
# We bin it because CTR is continuous and StratifiedKFold needs discrete categories
y_binned = pd.qcut(y['CTR_encoded'], q=5, labels=False, duplicates='drop')  

base_model = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42, objective="reg:squarederror")
multi_target_model = MultiOutputRegressor(base_model)

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

mse_scores_ctr = []
mse_scores_cpm = []
r2_scores_ctr = []
r2_scores_cpm = []

# Multi-Target Modeling with Cross-Validation
for fold_num, (train_index, test_index) in enumerate(skf.split(X, y_binned)):
    print(f"Fold {fold_num + 1}")
    
    X_train_fold = X.iloc[train_index]
    X_test_fold = X.iloc[test_index]

    y_train_fold = y.iloc[train_index]
    y_test_fold = y.iloc[test_index]

    # Init multi-target model
    multi_target_model.fit(X_train_fold, y_train_fold)
    y_pred = multi_target_model.predict(X_test_fold)

    # Calculate MSE and R² for CTR and CPM separately
    mse_ctr = mean_squared_error(y_test_fold['CTR_encoded'], y_pred[:, 0])
    mse_cpm = mean_squared_error(y_test_fold['AverageWinPrice (CPM)_encoded'], y_pred[:, 1])
    mse_scores_ctr.append(mse_ctr)
    mse_scores_cpm.append(mse_cpm)
    
    r2_ctr = r2_score(y_test_fold['CTR_encoded'], y_pred[:, 0])
    r2_cpm = r2_score(y_test_fold['AverageWinPrice (CPM)_encoded'], y_pred[:, 1])
    r2_scores_ctr.append(r2_ctr)
    r2_scores_cpm.append(r2_cpm)

    print(f"Training size: {len(X_train_fold)}, Validation size: {len(X_test_fold)}")
    print(f"Average CTR in training: {y_train_fold['CTR_encoded'].mean():.4f}")
    print(f"Average CTR in validation: {y_test_fold['CTR_encoded'].mean():.4f}")
    print(f"Average CPM in training: {y_train_fold['AverageWinPrice (CPM)_encoded'].mean():.4f}")
    print(f"Average CPM in validation: {y_test_fold['AverageWinPrice (CPM)_encoded'].mean():.4f}")
    print("\n")

#Calculate average cross-validation scores
print("Average Cross-Validation Scores:")
print(f"Average MSE for CTR: {np.mean(mse_scores_ctr):.4f}")
print(f"Average R2 for CTR: {np.mean(r2_scores_ctr):.4f}")
print('\n')
print(f"Average MSE for CPM: {np.mean(mse_scores_cpm):.4f}")
print(f"Average R2 for CPM: {np.mean(r2_scores_cpm):.4f}")
# Out:
# Fold 1
# Training size: 243693, Validation size: 60924
# Average CTR in training: 0.2071
# Average CTR in validation: 0.2069
# Average CPM in training: 0.2073
# Average CPM in validation: 0.2062
#
#
# Fold 2
# Training size: 243693, Validation size: 60924
# Average CTR in training: 0.2070
# Average CTR in validation: 0.2071
# Average CPM in training: 0.2071
# Average CPM in validation: 0.2068
#
#
# Fold 3
# Training size: 243694, Validation size: 60923
# Average CTR in training: 0.2070
# Average CTR in validation: 0.2072
# Average CPM in training: 0.2066
# Average CPM in validation: 0.2089
#
#
# Fold 4
# Training size: 243694, Validation size: 60923
# Average CTR in training: 0.2071
# Average CTR in validation: 0.2070
# Average CPM in training: 0.2067
# Average CPM in validation: 0.2083
#
#
# Fold 5
# Training size: 243694, Validation size: 60923
# Average CTR in training: 0.2071
# Average CTR in validation: 0.2070
# Average CPM in training: 0.2075
# Average CPM in validation: 0.2051
#
#
# Average Cross-Validation Scores:
# Average MSE for CTR: 0.0043
# Average R2 for CTR: 0.1126
#
#
# Average MSE for CPM: 0.0331
# Average R2 for CPM: 0.6998

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from scipy.stats import uniform, randint

# Define parameter grid for random search
param_distributions = {
    'estimator__n_estimators': randint(100, 1000),
    'estimator__max_depth': randint(3, 10),
    'estimator__learning_rate': uniform(0.01, 0.3),
    'estimator__subsample': uniform(0.6, 0.4),
    'estimator__colsample_bytree': uniform(0.6, 0.4),
    'estimator__min_child_weight': randint(1, 7),
    'estimator__gamma': uniform(0, 0.5)
}

# Create base model
base_model = XGBRegressor(
    objective='reg:squarederror',
    random_state=42
)
multi_target_model = MultiOutputRegressor(base_model)

# Initialize RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=multi_target_model,
    param_distributions=param_distributions,
    n_iter=50,  # Number of parameter settings sampled
    scoring='neg_mean_squared_error',
    cv=5,
    verbose=2,
    random_state=42,
    n_jobs=-1  # Use all available cores
)

# Fit RandomizedSearchCV
random_search.fit(X, y)

# Print results
print("\nBest parameters found:")
print(random_search.best_params_)
print("\nBest score:")
print(random_search.best_score_)

# Use the best parameters for your final model
best_model = MultiOutputRegressor(XGBRegressor(
    **{k.replace('estimator__', ''): v 
       for k, v in random_search.best_params_.items()},
    objective='reg:squarederror',
    random_state=42
))

# Optional: Plot feature importance for the best model
def plot_feature_importance(model, feature_names):
    importances = []
    for estimator in model.estimators_:
        importances.append(estimator.feature_importances_)
    
    # Average importance across both models (CTR and CPM)
    avg_importance = np.mean(importances, axis=0)
    
    # Create DataFrame of features and their importance scores
    importance_df = pd.DataFrame({
        'Feature': feature_names,
        'Importance': avg_importance
    })
    importance_df = importance_df.sort_values('Importance', ascending=False)
    
    # Plot
    plt.figure(figsize=(10, 6))
    sns.barplot(x='Importance', y='Feature', data=importance_df)
    plt.title('Average Feature Importance')
    plt.tight_layout()
    plt.show()

# After fitting the best model, plot feature importance
best_model.fit(X, y)
plot_feature_importance(best_model, X.columns)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END estimator__colsample_bytree=0.6399899663272012, estimator__gamma=0.22962444598293358, estimator__learning_rate=0.11011258334170654, estimator__max_depth=5, estimator__min_child_weight=6, estimator__n_estimators=408, estimator__subsample=0.9879639408647978; total time=  19.0s
# [CV] END estimator__colsample_bytree=0.6399899663272012, estimator__gamma=0.22962444598293358, estimator__learning_rate=0.11011258334170654, estimator__max_depth=5, estimator__min_child_weight=6, estimator__n_estimators=408, estimator__subsample=0.9879639408647978; total time=  19.4s
# [CV] END estimator__colsample_bytree=0.6399899663272012, estimator__gamma=0.22962444598293358, estimator__learning_rate=0.11011258334170654, estimator__max_depth=5, estimator__min_child_weight=6, estimator__n_estimators=408, estimator__subsample=0.9879639408647978; total time=  19.5s
# [CV] END estimator__colsample_bytree=0.6399899663272012, estimator__gamma=0.22962444598293358, estimator__learning_rate=0.11011258334170654, estimator__max_depth=5, estimator__min_child_weight=6, estimator__n_estimators=408, estimator__subsample=0.9879639408647978; total time=  19.6s
# [CV] END estimator__colsample_bytree=0.6399899663272012, estimator__gamma=0.22962444598293358, estimator__learning_rate=0.11011258334170654, estimator__max_depth=5, estimator__min_child_weight=6, estimator__n_estimators=408, estimator__subsample=0.9879639408647978; total time=  20.0s
# [CV] END estimator__colsample_bytree=0.749816047538945, estimator__gamma=0.4753571532049581, estimator__learning_rate=0.22959818254342154, estimator__max_depth=7, estimator__min_child_weight=5, estimator__n_estimators=714, estimator__subsample=0.7783331011414365; total time=  25.9s
# [CV] END estimator__colsample_bytree=0.749816047538945, estimator__gamma=0.4753571532049581, estimator__learning_rate=0.22959818254342154, estimator__max_depth=7, estimator__min_child_weight=5, estimator__n_estimators=714, estimator__subsample=0.7783331011414365; total time=  26.1s
# [CV] END estimator__colsample_bytree=0.749816047538945, estimator__gamma=0.4753571532049581, estimator__learning_rate=0.22959818254342154, estimator__max_depth=7, estimator__min_child_weight=5, estimator__n_estimators=714, estimator__subsample=0.7783331011414365; total time=  26.3s
# [CV] END estimator__colsample_bytree=0.749816047538945, estimator__gamma=0.4753571532049581, estimator__learning_rate=0.22959818254342154, estimator__max_depth=7, estimator__min_child_weight=5, estimator__n_estimators=714, estimator__subsample=0.7783331011414365; total time=  26.9s
# [CV] END estimator__colsample_bytree=0.749816047538945, estimator__gamma=0.4753571532049581, estimator__learning_rate=0.22959818254342154, estimator__max_depth=7, estimator__min_child_weight=5, estimator__n_estimators=714, estimator__subsample=0.7783331011414365; total time=  26.7s
# [CV] END estimator__colsample_bytree=0.6028265220878869, estimator__gamma=0.011531212520707879, estimator__learning_rate=0.16743239807751675, estimator__max_depth=9, estimator__min_child_weight=2, estimator__n_estimators=575, estimator__subsample=0.9895022075365837; total time=  34.2s
# [CV] END estimator__colsample_bytree=0.9329770563201687, estimator__gamma=0.10616955533913808, estimator__learning_rate=0.06454749016213018, estimator__max_depth=7, estimator__min_child_weight=1, estimator__n_estimators=559, estimator__subsample=0.8446612641953124; total time=  35.4s
# [CV] END estimator__colsample_bytree=0.9329770563201687, estimator__gamma=0.10616955533913808, estimator__learning_rate=0.06454749016213018, estimator__max_depth=7, estimator__min_child_weight=1, estimator__n_estimators=559, estimator__subsample=0.8446612641953124; total time=  35.7s
# [CV] END estimator__colsample_bytree=0.9329770563201687, estimator__gamma=0.10616955533913808, estimator__learning_rate=0.06454749016213018, estimator__max_depth=7, estimator__min_child_weight=1, estimator__n_estimators=559, estimator__subsample=0.8446612641953124; total time=  35.7s
# [CV] END estimator__colsample_bytree=0.9329770563201687, estimator__gamma=0.10616955533913808, estimator__learning_rate=0.06454749016213018, estimator__max_depth=7, estimator__min_child_weight=1, estimator__n_estimators=559, estimator__subsample=0.8446612641953124; total time=  36.2s
# [CV] END estimator__colsample_bytree=0.9329770563201687, estimator__gamma=0.10616955533913808, estimator__learning_rate=0.06454749016213018, estimator__max_depth=7, estimator__min_child_weight=1, estimator__n_estimators=559, estimator__subsample=0.8446612641953124; total time=  36.4s
# [CV] END estimator__colsample_bytree=0.9439761626945282, estimator__gamma=0.34015376929388985, estimator__learning_rate=0.1451497755908629, estimator__max_depth=4, estimator__min_child_weight=4, estimator__n_estimators=700, estimator__subsample=0.9862528132298237; total time=  25.9s
# [CV] END estimator__colsample_bytree=0.6028265220878869, estimator__gamma=0.011531212520707879, estimator__learning_rate=0.16743239807751675, estimator__max_depth=9, estimator__min_child_weight=2, estimator__n_estimators=575, estimator__subsample=0.9895022075365837; total time=  33.9s
# [CV] END estimator__colsample_bytree=0.6028265220878869, estimator__gamma=0.011531212520707879, estimator__learning_rate=0.16743239807751675, estimator__max_depth=9, estimator__min_child_weight=2, estimator__n_estimators=575, estimator__subsample=0.9895022075365837; total time=  33.7s
# [CV] END estimator__colsample_bytree=0.6028265220878869, estimator__gamma=0.011531212520707879, estimator__learning_rate=0.16743239807751675, estimator__max_depth=9, estimator__min_child_weight=2, estimator__n_estimators=575, estimator__subsample=0.9895022075365837; total time=  33.7s
# [CV] END estimator__colsample_bytree=0.6028265220878869, estimator__gamma=0.011531212520707879, estimator__learning_rate=0.16743239807751675, estimator__max_depth=9, estimator__min_child_weight=2, estimator__n_estimators=575, estimator__subsample=0.9895022075365837; total time=  33.7s
# [CV] END estimator__colsample_bytree=0.9439761626945282, estimator__gamma=0.34015376929388985, estimator__learning_rate=0.1451497755908629, estimator__max_depth=4, estimator__min_child_weight=4, estimator__n_estimators=700, estimator__subsample=0.9862528132298237; total time=  26.8s
# [CV] END estimator__colsample_bytree=0.9439761626945282, estimator__gamma=0.34015376929388985, estimator__learning_rate=0.1451497755908629, estimator__max_depth=4, estimator__min_child_weight=4, estimator__n_estimators=700, estimator__subsample=0.9862528132298237; total time=  27.0s
# [CV] END estimator__colsample_bytree=0.9439761626945282, estimator__gamma=0.34015376929388985, estimator__learning_rate=0.1451497755908629, estimator__max_depth=4, estimator__min_child_weight=4, estimator__n_estimators=700, estimator__subsample=0.9862528132298237; total time=  27.1s
# [CV] END estimator__colsample_bytree=0.9439761626945282, estimator__gamma=0.34015376929388985, estimator__learning_rate=0.1451497755908629, estimator__max_depth=4, estimator__min_child_weight=4, estimator__n_estimators=700, estimator__subsample=0.9862528132298237; total time=  27.2s
# [CV] END estimator__colsample_bytree=0.6931085361721216, estimator__gamma=0.0453032172664104, estimator__learning_rate=0.1955158027999262, estimator__max_depth=6, estimator__min_child_weight=4, estimator__n_estimators=931, estimator__subsample=0.786705157299192; total time=  55.8s
# [CV] END estimator__colsample_bytree=0.9233589392465844, estimator__gamma=0.15230688458668534, estimator__learning_rate=0.03930163420191516, estimator__max_depth=6, estimator__min_child_weight=4, estimator__n_estimators=466, estimator__subsample=0.8733054075301833; total time=  39.7s
# [CV] END estimator__colsample_bytree=0.9233589392465844, estimator__gamma=0.15230688458668534, estimator__learning_rate=0.03930163420191516, estimator__max_depth=6, estimator__min_child_weight=4, estimator__n_estimators=466, estimator__subsample=0.8733054075301833; total time=  39.6s
# [CV] END estimator__colsample_bytree=0.6931085361721216, estimator__gamma=0.0453032172664104, estimator__learning_rate=0.1955158027999262, estimator__max_depth=6, estimator__min_child_weight=4, estimator__n_estimators=931, estimator__subsample=0.786705157299192; total time=  54.2s
# [CV] END estimator__colsample_bytree=0.6931085361721216, estimator__gamma=0.0453032172664104, estimator__learning_rate=0.1955158027999262, estimator__max_depth=6, estimator__min_child_weight=4, estimator__n_estimators=931, estimator__subsample=0.786705157299192; total time=  54.6s
# [CV] END estimator__colsample_bytree=0.6931085361721216, estimator__gamma=0.0453032172664104, estimator__learning_rate=0.1955158027999262, estimator__max_depth=6, estimator__min_child_weight=4, estimator__n_estimators=931, estimator__subsample=0.786705157299192; total time=  56.3s
# [CV] END estimator__colsample_bytree=0.6931085361721216, estimator__gamma=0.0453032172664104, estimator__learning_rate=0.1955158027999262, estimator__max_depth=6, estimator__min_child_weight=4, estimator__n_estimators=931, estimator__subsample=0.786705157299192; total time=  56.3s
# [CV] END estimator__colsample_bytree=0.8439986631130484, estimator__gamma=0.41659745586808217, estimator__learning_rate=0.062009396052331626, estimator__max_depth=3, estimator__min_child_weight=4, estimator__n_estimators=661, estimator__subsample=0.8650089137415928; total time=  33.8s
# [CV] END estimator__colsample_bytree=0.8439986631130484, estimator__gamma=0.41659745586808217, estimator__learning_rate=0.062009396052331626, estimator__max_depth=3, estimator__min_child_weight=4, estimator__n_estimators=661, estimator__subsample=0.8650089137415928; total time=  34.3s
# [CV] END estimator__colsample_bytree=0.9233589392465844, estimator__gamma=0.15230688458668534, estimator__learning_rate=0.03930163420191516, estimator__max_depth=6, estimator__min_child_weight=4, estimator__n_estimators=466, estimator__subsample=0.8733054075301833; total time=  38.7s
# [CV] END estimator__colsample_bytree=0.9233589392465844, estimator__gamma=0.15230688458668534, estimator__learning_rate=0.03930163420191516, estimator__max_depth=6, estimator__min_child_weight=4, estimator__n_estimators=466, estimator__subsample=0.8733054075301833; total time=  39.1s
# [CV] END estimator__colsample_bytree=0.9233589392465844, estimator__gamma=0.15230688458668534, estimator__learning_rate=0.03930163420191516, estimator__max_depth=6, estimator__min_child_weight=4, estimator__n_estimators=466, estimator__subsample=0.8733054075301833; total time=  39.8s
# [CV] END estimator__colsample_bytree=0.7246844304357644, estimator__gamma=0.2600340105889054, estimator__learning_rate=0.1740130838029839, estimator__max_depth=8, estimator__min_child_weight=5, estimator__n_estimators=802, estimator__subsample=0.9369139098379994; total time=  31.2s
# [CV] END estimator__colsample_bytree=0.8439986631130484, estimator__gamma=0.41659745586808217, estimator__learning_rate=0.062009396052331626, estimator__max_depth=3, estimator__min_child_weight=4, estimator__n_estimators=661, estimator__subsample=0.8650089137415928; total time=  35.1s
# [CV] END estimator__colsample_bytree=0.8439986631130484, estimator__gamma=0.41659745586808217, estimator__learning_rate=0.062009396052331626, estimator__max_depth=3, estimator__min_child_weight=4, estimator__n_estimators=661, estimator__subsample=0.8650089137415928; total time=  35.5s
# [CV] END estimator__colsample_bytree=0.8439986631130484, estimator__gamma=0.41659745586808217, estimator__learning_rate=0.062009396052331626, estimator__max_depth=3, estimator__min_child_weight=4, estimator__n_estimators=661, estimator__subsample=0.8650089137415928; total time=  36.3s
# [CV] END estimator__colsample_bytree=0.7246844304357644, estimator__gamma=0.2600340105889054, estimator__learning_rate=0.1740130838029839, estimator__max_depth=8, estimator__min_child_weight=5, estimator__n_estimators=802, estimator__subsample=0.9369139098379994; total time=  54.8s
# [CV] END estimator__colsample_bytree=0.7246844304357644, estimator__gamma=0.2600340105889054, estimator__learning_rate=0.1740130838029839, estimator__max_depth=8, estimator__min_child_weight=5, estimator__n_estimators=802, estimator__subsample=0.9369139098379994; total time=  57.6s
# [CV] END estimator__colsample_bytree=0.7246844304357644, estimator__gamma=0.2600340105889054, estimator__learning_rate=0.1740130838029839, estimator__max_depth=8, estimator__min_child_weight=5, estimator__n_estimators=802, estimator__subsample=0.9369139098379994; total time=  58.2s
# [CV] END estimator__colsample_bytree=0.7246844304357644, estimator__gamma=0.2600340105889054, estimator__learning_rate=0.1740130838029839, estimator__max_depth=8, estimator__min_child_weight=5, estimator__n_estimators=802, estimator__subsample=0.9369139098379994; total time= 1.1min
# [CV] END estimator__colsample_bytree=0.7799016533479063, estimator__gamma=0.1975751180009072, estimator__learning_rate=0.28799765973813823, estimator__max_depth=9, estimator__min_child_weight=6, estimator__n_estimators=826, estimator__subsample=0.8083337040103294; total time= 1.1min
# [CV] END estimator__colsample_bytree=0.7799016533479063, estimator__gamma=0.1975751180009072, estimator__learning_rate=0.28799765973813823, estimator__max_depth=9, estimator__min_child_weight=6, estimator__n_estimators=826, estimator__subsample=0.8083337040103294; total time= 1.1min
# [CV] END estimator__colsample_bytree=0.7799016533479063, estimator__gamma=0.1975751180009072, estimator__learning_rate=0.28799765973813823, estimator__max_depth=9, estimator__min_child_weight=6, estimator__n_estimators=826, estimator__subsample=0.8083337040103294; total time= 1.1min
# [CV] END estimator__colsample_bytree=0.7123738038749523, estimator__gamma=0.27134804157912423, estimator__learning_rate=0.052277267492428794, estimator__max_depth=9, estimator__min_child_weight=5, estimator__n_estimators=164, estimator__subsample=0.6062545626964776; total time=  49.0s
# [CV] END estimator__colsample_bytree=0.7123738038749523, estimator__gamma=0.27134804157912423, estimator__learning_rate=0.052277267492428794, estimator__max_depth=9, estimator__min_child_weight=5, estimator__n_estimators=164, estimator__subsample=0.6062545626964776; total time=  48.9s
# [CV] END estimator__colsample_bytree=0.7799016533479063, estimator__gamma=0.1975751180009072, estimator__learning_rate=0.28799765973813823, estimator__max_depth=9, estimator__min_child_weight=6, estimator__n_estimators=826, estimator__subsample=0.8083337040103294; total time= 1.1min
# [CV] END estimator__colsample_bytree=0.7799016533479063, estimator__gamma=0.1975751180009072, estimator__learning_rate=0.28799765973813823, estimator__max_depth=9, estimator__min_child_weight=6, estimator__n_estimators=826, estimator__subsample=0.8083337040103294; total time= 1.1min
# [CV] END estimator__colsample_bytree=0.7123738038749523, estimator__gamma=0.27134804157912423, estimator__learning_rate=0.052277267492428794, estimator__max_depth=9, estimator__min_child_weight=5, estimator__n_estimators=164, estimator__subsample=0.6062545626964776; total time=  26.3s
# [CV] END estimator__colsample_bytree=0.7123738038749523, estimator__gamma=0.27134804157912423, estimator__learning_rate=0.052277267492428794, estimator__max_depth=9, estimator__min_child_weight=5, estimator__n_estimators=164, estimator__subsample=0.6062545626964776; total time=  22.9s
# [CV] END estimator__colsample_bytree=0.7123738038749523, estimator__gamma=0.27134804157912423, estimator__learning_rate=0.052277267492428794, estimator__max_depth=9, estimator__min_child_weight=5, estimator__n_estimators=164, estimator__subsample=0.6062545626964776; total time=  23.4s
# [CV] END estimator__colsample_bytree=0.9844688097397396, estimator__gamma=0.4222669243390757, estimator__learning_rate=0.23419603304121425, estimator__max_depth=9, estimator__min_child_weight=5, estimator__n_estimators=891, estimator__subsample=0.7427013306774357; total time= 1.1min
# [CV] END estimator__colsample_bytree=0.9844688097397396, estimator__gamma=0.4222669243390757, estimator__learning_rate=0.23419603304121425, estimator__max_depth=9, estimator__min_child_weight=5, estimator__n_estimators=891, estimator__subsample=0.7427013306774357; total time= 1.1min
# [CV] END estimator__colsample_bytree=0.9844688097397396, estimator__gamma=0.4222669243390757, estimator__learning_rate=0.23419603304121425, estimator__max_depth=9, estimator__min_child_weight=5, estimator__n_estimators=891, estimator__subsample=0.7427013306774357; total time= 1.1min
# [CV] END estimator__colsample_bytree=0.9844688097397396, estimator__gamma=0.4222669243390757, estimator__learning_rate=0.23419603304121425, estimator__max_depth=9, estimator__min_child_weight=5, estimator__n_estimators=891, estimator__subsample=0.7427013306774357; total time= 1.1min
# [CV] END estimator__colsample_bytree=0.9844688097397396, estimator__gamma=0.4222669243390757, estimator__learning_rate=0.23419603304121425, estimator__max_depth=9, estimator__min_child_weight=5, estimator__n_estimators=891, estimator__subsample=0.7427013306774357; total time= 1.1min
# [CV] END estimator__colsample_bytree=0.8916028672163949, estimator__gamma=0.38563517334297287, estimator__learning_rate=0.03221339552022711, estimator__max_depth=9, estimator__min_child_weight=2, estimator__n_estimators=140, estimator__subsample=0.9659838702175123; total time=  21.5s
# [CV] END estimator__colsample_bytree=0.7693605922825478, estimator__gamma=0.19744075908778486, estimator__learning_rate=0.09804645241541143, estimator__max_depth=9, estimator__min_child_weight=3, estimator__n_estimators=598, estimator__subsample=0.8827429375390468; total time=  27.6s
# [CV] END estimator__colsample_bytree=0.7693605922825478, estimator__gamma=0.19744075908778486, estimator__learning_rate=0.09804645241541143, estimator__max_depth=9, estimator__min_child_weight=3, estimator__n_estimators=598, estimator__subsample=0.8827429375390468; total time=  27.5s
# [CV] END estimator__colsample_bytree=0.7693605922825478, estimator__gamma=0.19744075908778486, estimator__learning_rate=0.09804645241541143, estimator__max_depth=9, estimator__min_child_weight=3, estimator__n_estimators=598, estimator__subsample=0.8827429375390468; total time=  27.0s
# [CV] END estimator__colsample_bytree=0.8916028672163949, estimator__gamma=0.38563517334297287, estimator__learning_rate=0.03221339552022711, estimator__max_depth=9, estimator__min_child_weight=2, estimator__n_estimators=140, estimator__subsample=0.9659838702175123; total time=  21.2s
# [CV] END estimator__colsample_bytree=0.7693605922825478, estimator__gamma=0.19744075908778486, estimator__learning_rate=0.09804645241541143, estimator__max_depth=9, estimator__min_child_weight=3, estimator__n_estimators=598, estimator__subsample=0.8827429375390468; total time=  27.1s
# [CV] END estimator__colsample_bytree=0.8916028672163949, estimator__gamma=0.38563517334297287, estimator__learning_rate=0.03221339552022711, estimator__max_depth=9, estimator__min_child_weight=2, estimator__n_estimators=140, estimator__subsample=0.9659838702175123; total time=  21.2s
# [CV] END estimator__colsample_bytree=0.7693605922825478, estimator__gamma=0.19744075908778486, estimator__learning_rate=0.09804645241541143, estimator__max_depth=9, estimator__min_child_weight=3, estimator__n_estimators=598, estimator__subsample=0.8827429375390468; total time=  27.3s
# [CV] END estimator__colsample_bytree=0.8916028672163949, estimator__gamma=0.38563517334297287, estimator__learning_rate=0.03221339552022711, estimator__max_depth=9, estimator__min_child_weight=2, estimator__n_estimators=140, estimator__subsample=0.9659838702175123; total time=  21.2s
# [CV] END estimator__colsample_bytree=0.8916028672163949, estimator__gamma=0.38563517334297287, estimator__learning_rate=0.03221339552022711, estimator__max_depth=9, estimator__min_child_weight=2, estimator__n_estimators=140, estimator__subsample=0.9659838702175123; total time=  21.7s
# [CV] END estimator__colsample_bytree=0.8365191150830908, estimator__gamma=0.13736089649503208, estimator__learning_rate=0.17837302775431035, estimator__max_depth=5, estimator__min_child_weight=5, estimator__n_estimators=561, estimator__subsample=0.9395655297064336; total time=  24.1s
# [CV] END estimator__colsample_bytree=0.8365191150830908, estimator__gamma=0.13736089649503208, estimator__learning_rate=0.17837302775431035, estimator__max_depth=5, estimator__min_child_weight=5, estimator__n_estimators=561, estimator__subsample=0.9395655297064336; total time=  25.3s
# [CV] END estimator__colsample_bytree=0.8365191150830908, estimator__gamma=0.13736089649503208, estimator__learning_rate=0.17837302775431035, estimator__max_depth=5, estimator__min_child_weight=5, estimator__n_estimators=561, estimator__subsample=0.9395655297064336; total time=  25.3s
# [CV] END estimator__colsample_bytree=0.8365191150830908, estimator__gamma=0.13736089649503208, estimator__learning_rate=0.17837302775431035, estimator__max_depth=5, estimator__min_child_weight=5, estimator__n_estimators=561, estimator__subsample=0.9395655297064336; total time=  25.6s
# [CV] END estimator__colsample_bytree=0.8886918084659492, estimator__gamma=0.11799245987447787, estimator__learning_rate=0.08682049682839718, estimator__max_depth=5, estimator__min_child_weight=1, estimator__n_estimators=306, estimator__subsample=0.7710164073434198; total time=  24.6s
# [CV] END estimator__colsample_bytree=0.8886918084659492, estimator__gamma=0.11799245987447787, estimator__learning_rate=0.08682049682839718, estimator__max_depth=5, estimator__min_child_weight=1, estimator__n_estimators=306, estimator__subsample=0.7710164073434198; total time=  24.9s
# [CV] END estimator__colsample_bytree=0.8365191150830908, estimator__gamma=0.13736089649503208, estimator__learning_rate=0.17837302775431035, estimator__max_depth=5, estimator__min_child_weight=5, estimator__n_estimators=561, estimator__subsample=0.9395655297064336; total time=  25.5s
# [CV] END estimator__colsample_bytree=0.8886918084659492, estimator__gamma=0.11799245987447787, estimator__learning_rate=0.08682049682839718, estimator__max_depth=5, estimator__min_child_weight=1, estimator__n_estimators=306, estimator__subsample=0.7710164073434198; total time=  24.5s
# [CV] END estimator__colsample_bytree=0.8886918084659492, estimator__gamma=0.11799245987447787, estimator__learning_rate=0.08682049682839718, estimator__max_depth=5, estimator__min_child_weight=1, estimator__n_estimators=306, estimator__subsample=0.7710164073434198; total time=  24.9s
# [CV] END estimator__colsample_bytree=0.8886918084659492, estimator__gamma=0.11799245987447787, estimator__learning_rate=0.08682049682839718, estimator__max_depth=5, estimator__min_child_weight=1, estimator__n_estimators=306, estimator__subsample=0.7710164073434198; total time=  24.8s
# [CV] END estimator__colsample_bytree=0.9400154311159197, estimator__gamma=0.2247253370691017, estimator__learning_rate=0.038623034947123394, estimator__max_depth=9, estimator__min_child_weight=6, estimator__n_estimators=827, estimator__subsample=0.8663689426469987; total time=  46.5s
# [CV] END estimator__colsample_bytree=0.9400154311159197, estimator__gamma=0.2247253370691017, estimator__learning_rate=0.038623034947123394, estimator__max_depth=9, estimator__min_child_weight=6, estimator__n_estimators=827, estimator__subsample=0.8663689426469987; total time=  46.0s
# [CV] END estimator__colsample_bytree=0.9400154311159197, estimator__gamma=0.2247253370691017, estimator__learning_rate=0.038623034947123394, estimator__max_depth=9, estimator__min_child_weight=6, estimator__n_estimators=827, estimator__subsample=0.8663689426469987; total time=  45.6s
# [CV] END estimator__colsample_bytree=0.9400154311159197, estimator__gamma=0.2247253370691017, estimator__learning_rate=0.038623034947123394, estimator__max_depth=9, estimator__min_child_weight=6, estimator__n_estimators=827, estimator__subsample=0.8663689426469987; total time=  45.8s
# [CV] END estimator__colsample_bytree=0.9400154311159197, estimator__gamma=0.2247253370691017, estimator__learning_rate=0.038623034947123394, estimator__max_depth=9, estimator__min_child_weight=6, estimator__n_estimators=827, estimator__subsample=0.8663689426469987; total time=  45.9s
# [CV] END estimator__colsample_bytree=0.6421977039321082, estimator__gamma=0.22826728524145512, estimator__learning_rate=0.07553213116505007, estimator__max_depth=6, estimator__min_child_weight=6, estimator__n_estimators=430, estimator__subsample=0.7297380084021096; total time=  27.9s
# [CV] END estimator__colsample_bytree=0.878206434570451, estimator__gamma=0.06966572720293784, estimator__learning_rate=0.1913252137833452, estimator__max_depth=9, estimator__min_child_weight=3, estimator__n_estimators=640, estimator__subsample=0.6915192661966489; total time=  36.5s
# [CV] END estimator__colsample_bytree=0.878206434570451, estimator__gamma=0.06966572720293784, estimator__learning_rate=0.1913252137833452, estimator__max_depth=9, estimator__min_child_weight=3, estimator__n_estimators=640, estimator__subsample=0.6915192661966489; total time=  37.7s
# [CV] END estimator__colsample_bytree=0.878206434570451, estimator__gamma=0.06966572720293784, estimator__learning_rate=0.1913252137833452, estimator__max_depth=9, estimator__min_child_weight=3, estimator__n_estimators=640, estimator__subsample=0.6915192661966489; total time=  36.9s
# [CV] END estimator__colsample_bytree=0.878206434570451, estimator__gamma=0.06966572720293784, estimator__learning_rate=0.1913252137833452, estimator__max_depth=9, estimator__min_child_weight=3, estimator__n_estimators=640, estimator__subsample=0.6915192661966489; total time=  38.2s
# [CV] END estimator__colsample_bytree=0.878206434570451, estimator__gamma=0.06966572720293784, estimator__learning_rate=0.1913252137833452, estimator__max_depth=9, estimator__min_child_weight=3, estimator__n_estimators=640, estimator__subsample=0.6915192661966489; total time=  38.2s
# [CV] END estimator__colsample_bytree=0.6307919639315172, estimator__gamma=0.144875726456884, estimator__learning_rate=0.058366386176201324, estimator__max_depth=4, estimator__min_child_weight=2, estimator__n_estimators=656, estimator__subsample=0.7182534743350856; total time=  44.6s
# [CV] END estimator__colsample_bytree=0.6307919639315172, estimator__gamma=0.144875726456884, estimator__learning_rate=0.058366386176201324, estimator__max_depth=4, estimator__min_child_weight=2, estimator__n_estimators=656, estimator__subsample=0.7182534743350856; total time=  45.1s
# [CV] END estimator__colsample_bytree=0.6307919639315172, estimator__gamma=0.144875726456884, estimator__learning_rate=0.058366386176201324, estimator__max_depth=4, estimator__min_child_weight=2, estimator__n_estimators=656, estimator__subsample=0.7182534743350856; total time=  45.8s
# [CV] END estimator__colsample_bytree=0.6307919639315172, estimator__gamma=0.144875726456884, estimator__learning_rate=0.058366386176201324, estimator__max_depth=4, estimator__min_child_weight=2, estimator__n_estimators=656, estimator__subsample=0.7182534743350856; total time=  45.4s
# [CV] END estimator__colsample_bytree=0.6307919639315172, estimator__gamma=0.144875726456884, estimator__learning_rate=0.058366386176201324, estimator__max_depth=4, estimator__min_child_weight=2, estimator__n_estimators=656, estimator__subsample=0.7182534743350856; total time=  45.5s
# [CV] END estimator__colsample_bytree=0.6488351818802693, estimator__gamma=0.17814891903848745, estimator__learning_rate=0.2820485324637262, estimator__max_depth=3, estimator__min_child_weight=1, estimator__n_estimators=382, estimator__subsample=0.7708431154505025; total time=  22.1s
# [CV] END estimator__colsample_bytree=0.6488351818802693, estimator__gamma=0.17814891903848745, estimator__learning_rate=0.2820485324637262, estimator__max_depth=3, estimator__min_child_weight=1, estimator__n_estimators=382, estimator__subsample=0.7708431154505025; total time=  22.7s
# [CV] END estimator__colsample_bytree=0.6421977039321082, estimator__gamma=0.22826728524145512, estimator__learning_rate=0.07553213116505007, estimator__max_depth=6, estimator__min_child_weight=6, estimator__n_estimators=430, estimator__subsample=0.7297380084021096; total time=  27.9s
# [CV] END estimator__colsample_bytree=0.6421977039321082, estimator__gamma=0.22826728524145512, estimator__learning_rate=0.07553213116505007, estimator__max_depth=6, estimator__min_child_weight=6, estimator__n_estimators=430, estimator__subsample=0.7297380084021096; total time=  28.2s
# [CV] END estimator__colsample_bytree=0.6421977039321082, estimator__gamma=0.22826728524145512, estimator__learning_rate=0.07553213116505007, estimator__max_depth=6, estimator__min_child_weight=6, estimator__n_estimators=430, estimator__subsample=0.7297380084021096; total time=  28.1s
# [CV] END estimator__colsample_bytree=0.6421977039321082, estimator__gamma=0.22826728524145512, estimator__learning_rate=0.07553213116505007, estimator__max_depth=6, estimator__min_child_weight=6, estimator__n_estimators=430, estimator__subsample=0.7297380084021096; total time=  28.3s
# [CV] END estimator__colsample_bytree=0.6488351818802693, estimator__gamma=0.17814891903848745, estimator__learning_rate=0.2820485324637262, estimator__max_depth=3, estimator__min_child_weight=1, estimator__n_estimators=382, estimator__subsample=0.7708431154505025; total time=  22.2s
# [CV] END estimator__colsample_bytree=0.610167650697638, estimator__gamma=0.053945713496652226, estimator__learning_rate=0.019428755706020276, estimator__max_depth=9, estimator__min_child_weight=1, estimator__n_estimators=663, estimator__subsample=0.8253102287905535; total time= 1.5min
# [CV] END estimator__colsample_bytree=0.6488351818802693, estimator__gamma=0.17814891903848745, estimator__learning_rate=0.2820485324637262, estimator__max_depth=3, estimator__min_child_weight=1, estimator__n_estimators=382, estimator__subsample=0.7708431154505025; total time=  21.9s
# [CV] END estimator__colsample_bytree=0.6488351818802693, estimator__gamma=0.17814891903848745, estimator__learning_rate=0.2820485324637262, estimator__max_depth=3, estimator__min_child_weight=1, estimator__n_estimators=382, estimator__subsample=0.7708431154505025; total time=  22.0s
# [CV] END estimator__colsample_bytree=0.610167650697638, estimator__gamma=0.053945713496652226, estimator__learning_rate=0.019428755706020276, estimator__max_depth=9, estimator__min_child_weight=1, estimator__n_estimators=663, estimator__subsample=0.8253102287905535; total time= 1.5min
# [CV] END estimator__colsample_bytree=0.610167650697638, estimator__gamma=0.053945713496652226, estimator__learning_rate=0.019428755706020276, estimator__max_depth=9, estimator__min_child_weight=1, estimator__n_estimators=663, estimator__subsample=0.8253102287905535; total time= 1.4min
# [CV] END estimator__colsample_bytree=0.610167650697638, estimator__gamma=0.053945713496652226, estimator__learning_rate=0.019428755706020276, estimator__max_depth=9, estimator__min_child_weight=1, estimator__n_estimators=663, estimator__subsample=0.8253102287905535; total time= 1.5min
# [CV] END estimator__colsample_bytree=0.9887128330883843, estimator__gamma=0.4812236474710556, estimator__learning_rate=0.08553468874760924, estimator__max_depth=4, estimator__min_child_weight=3, estimator__n_estimators=212, estimator__subsample=0.6592347719813599; total time=  14.5s
# [CV] END estimator__colsample_bytree=0.9887128330883843, estimator__gamma=0.4812236474710556, estimator__learning_rate=0.08553468874760924, estimator__max_depth=4, estimator__min_child_weight=3, estimator__n_estimators=212, estimator__subsample=0.6592347719813599; total time=  14.7s
# [CV] END estimator__colsample_bytree=0.610167650697638, estimator__gamma=0.053945713496652226, estimator__learning_rate=0.019428755706020276, estimator__max_depth=9, estimator__min_child_weight=1, estimator__n_estimators=663, estimator__subsample=0.8253102287905535; total time= 1.5min
# [CV] END estimator__colsample_bytree=0.9272059063689972, estimator__gamma=0.4303652916281717, estimator__learning_rate=0.01208563915935721, estimator__max_depth=5, estimator__min_child_weight=1, estimator__n_estimators=417, estimator__subsample=0.6888431241882921; total time=  37.7s
# [CV] END estimator__colsample_bytree=0.9887128330883843, estimator__gamma=0.4812236474710556, estimator__learning_rate=0.08553468874760924, estimator__max_depth=4, estimator__min_child_weight=3, estimator__n_estimators=212, estimator__subsample=0.6592347719813599; total time=  15.1s
# [CV] END estimator__colsample_bytree=0.9272059063689972, estimator__gamma=0.4303652916281717, estimator__learning_rate=0.01208563915935721, estimator__max_depth=5, estimator__min_child_weight=1, estimator__n_estimators=417, estimator__subsample=0.6888431241882921; total time=  41.8s
# [CV] END estimator__colsample_bytree=0.6479461469334731, estimator__gamma=0.16880758570181398, estimator__learning_rate=0.29287291117375575, estimator__max_depth=8, estimator__min_child_weight=1, estimator__n_estimators=791, estimator__subsample=0.7454518409517176; total time=  31.9s
# [CV] END estimator__colsample_bytree=0.9887128330883843, estimator__gamma=0.4812236474710556, estimator__learning_rate=0.08553468874760924, estimator__max_depth=4, estimator__min_child_weight=3, estimator__n_estimators=212, estimator__subsample=0.6592347719813599; total time=  14.7s
# [CV] END estimator__colsample_bytree=0.9272059063689972, estimator__gamma=0.4303652916281717, estimator__learning_rate=0.01208563915935721, estimator__max_depth=5, estimator__min_child_weight=1, estimator__n_estimators=417, estimator__subsample=0.6888431241882921; total time=  37.0s
# [CV] END estimator__colsample_bytree=0.6479461469334731, estimator__gamma=0.16880758570181398, estimator__learning_rate=0.29287291117375575, estimator__max_depth=8, estimator__min_child_weight=1, estimator__n_estimators=791, estimator__subsample=0.7454518409517176; total time=  31.7s
# [CV] END estimator__colsample_bytree=0.9272059063689972, estimator__gamma=0.4303652916281717, estimator__learning_rate=0.01208563915935721, estimator__max_depth=5, estimator__min_child_weight=1, estimator__n_estimators=417, estimator__subsample=0.6888431241882921; total time=  36.6s
# [CV] END estimator__colsample_bytree=0.9887128330883843, estimator__gamma=0.4812236474710556, estimator__learning_rate=0.08553468874760924, estimator__max_depth=4, estimator__min_child_weight=3, estimator__n_estimators=212, estimator__subsample=0.6592347719813599; total time=  14.6s
# [CV] END estimator__colsample_bytree=0.6479461469334731, estimator__gamma=0.16880758570181398, estimator__learning_rate=0.29287291117375575, estimator__max_depth=8, estimator__min_child_weight=1, estimator__n_estimators=791, estimator__subsample=0.7454518409517176; total time=  32.1s
# [CV] END estimator__colsample_bytree=0.9272059063689972, estimator__gamma=0.4303652916281717, estimator__learning_rate=0.01208563915935721, estimator__max_depth=5, estimator__min_child_weight=1, estimator__n_estimators=417, estimator__subsample=0.6888431241882921; total time=  36.6s
# [CV] END estimator__colsample_bytree=0.6479461469334731, estimator__gamma=0.16880758570181398, estimator__learning_rate=0.29287291117375575, estimator__max_depth=8, estimator__min_child_weight=1, estimator__n_estimators=791, estimator__subsample=0.7454518409517176; total time=  30.9s
# [CV] END estimator__colsample_bytree=0.6479461469334731, estimator__gamma=0.16880758570181398, estimator__learning_rate=0.29287291117375575, estimator__max_depth=8, estimator__min_child_weight=1, estimator__n_estimators=791, estimator__subsample=0.7454518409517176; total time=  31.3s
# [CV] END estimator__colsample_bytree=0.9933692563579372, estimator__gamma=0.19941222122227653, estimator__learning_rate=0.2549295619658152, estimator__max_depth=3, estimator__min_child_weight=1, estimator__n_estimators=223, estimator__subsample=0.8032795106962874; total time=  14.6s
# [CV] END estimator__colsample_bytree=0.8370786895517575, estimator__gamma=0.040426663166357624, estimator__learning_rate=0.12089633681842132, estimator__max_depth=3, estimator__min_child_weight=6, estimator__n_estimators=379, estimator__subsample=0.7881202537784153; total time=  26.2s
# [CV] END estimator__colsample_bytree=0.8370786895517575, estimator__gamma=0.040426663166357624, estimator__learning_rate=0.12089633681842132, estimator__max_depth=3, estimator__min_child_weight=6, estimator__n_estimators=379, estimator__subsample=0.7881202537784153; total time=  26.7s
# [CV] END estimator__colsample_bytree=0.8370786895517575, estimator__gamma=0.040426663166357624, estimator__learning_rate=0.12089633681842132, estimator__max_depth=3, estimator__min_child_weight=6, estimator__n_estimators=379, estimator__subsample=0.7881202537784153; total time=  27.4s
# [CV] END estimator__colsample_bytree=0.8370786895517575, estimator__gamma=0.040426663166357624, estimator__learning_rate=0.12089633681842132, estimator__max_depth=3, estimator__min_child_weight=6, estimator__n_estimators=379, estimator__subsample=0.7881202537784153; total time=  27.2s
# [CV] END estimator__colsample_bytree=0.9990961940195767, estimator__gamma=0.1333905071376425, estimator__learning_rate=0.3029844867497959, estimator__max_depth=6, estimator__min_child_weight=6, estimator__n_estimators=954, estimator__subsample=0.7114585856946446; total time=  43.1s
# [CV] END estimator__colsample_bytree=0.9990961940195767, estimator__gamma=0.1333905071376425, estimator__learning_rate=0.3029844867497959, estimator__max_depth=6, estimator__min_child_weight=6, estimator__n_estimators=954, estimator__subsample=0.7114585856946446; total time=  42.6s
# [CV] END estimator__colsample_bytree=0.8370786895517575, estimator__gamma=0.040426663166357624, estimator__learning_rate=0.12089633681842132, estimator__max_depth=3, estimator__min_child_weight=6, estimator__n_estimators=379, estimator__subsample=0.7881202537784153; total time=  28.6s
# [CV] END estimator__colsample_bytree=0.9990961940195767, estimator__gamma=0.1333905071376425, estimator__learning_rate=0.3029844867497959, estimator__max_depth=6, estimator__min_child_weight=6, estimator__n_estimators=954, estimator__subsample=0.7114585856946446; total time=  43.8s
# [CV] END estimator__colsample_bytree=0.9933692563579372, estimator__gamma=0.19941222122227653, estimator__learning_rate=0.2549295619658152, estimator__max_depth=3, estimator__min_child_weight=1, estimator__n_estimators=223, estimator__subsample=0.8032795106962874; total time=  13.7s
# [CV] END estimator__colsample_bytree=0.9990961940195767, estimator__gamma=0.1333905071376425, estimator__learning_rate=0.3029844867497959, estimator__max_depth=6, estimator__min_child_weight=6, estimator__n_estimators=954, estimator__subsample=0.7114585856946446; total time=  42.4s
# [CV] END estimator__colsample_bytree=0.9990961940195767, estimator__gamma=0.1333905071376425, estimator__learning_rate=0.3029844867497959, estimator__max_depth=6, estimator__min_child_weight=6, estimator__n_estimators=954, estimator__subsample=0.7114585856946446; total time=  42.1s
# [CV] END estimator__colsample_bytree=0.9933692563579372, estimator__gamma=0.19941222122227653, estimator__learning_rate=0.2549295619658152, estimator__max_depth=3, estimator__min_child_weight=1, estimator__n_estimators=223, estimator__subsample=0.8032795106962874; total time=  13.3s
# [CV] END estimator__colsample_bytree=0.9933692563579372, estimator__gamma=0.19941222122227653, estimator__learning_rate=0.2549295619658152, estimator__max_depth=3, estimator__min_child_weight=1, estimator__n_estimators=223, estimator__subsample=0.8032795106962874; total time=  14.5s
# [CV] END estimator__colsample_bytree=0.9633063543866615, estimator__gamma=0.11978094533348621, estimator__learning_rate=0.05346846162736693, estimator__max_depth=6, estimator__min_child_weight=2, estimator__n_estimators=771, estimator__subsample=0.8211572356285312; total time=  47.0s
# [CV] END estimator__colsample_bytree=0.9933692563579372, estimator__gamma=0.19941222122227653, estimator__learning_rate=0.2549295619658152, estimator__max_depth=3, estimator__min_child_weight=1, estimator__n_estimators=223, estimator__subsample=0.8032795106962874; total time=  14.8s
# [CV] END estimator__colsample_bytree=0.9633063543866615, estimator__gamma=0.11978094533348621, estimator__learning_rate=0.05346846162736693, estimator__max_depth=6, estimator__min_child_weight=2, estimator__n_estimators=771, estimator__subsample=0.8211572356285312; total time=  47.0s
# [CV] END estimator__colsample_bytree=0.9633063543866615, estimator__gamma=0.11978094533348621, estimator__learning_rate=0.05346846162736693, estimator__max_depth=6, estimator__min_child_weight=2, estimator__n_estimators=771, estimator__subsample=0.8211572356285312; total time=  47.3s
# [CV] END estimator__colsample_bytree=0.9633063543866615, estimator__gamma=0.11978094533348621, estimator__learning_rate=0.05346846162736693, estimator__max_depth=6, estimator__min_child_weight=2, estimator__n_estimators=771, estimator__subsample=0.8211572356285312; total time=  50.2s
# [CV] END estimator__colsample_bytree=0.9633063543866615, estimator__gamma=0.11978094533348621, estimator__learning_rate=0.05346846162736693, estimator__max_depth=6, estimator__min_child_weight=2, estimator__n_estimators=771, estimator__subsample=0.8211572356285312; total time=  50.6s
# [CV] END estimator__colsample_bytree=0.8783251227163527, estimator__gamma=0.4291794024068599, estimator__learning_rate=0.10778767156056542, estimator__max_depth=6, estimator__min_child_weight=3, estimator__n_estimators=445, estimator__subsample=0.8048372233197124; total time=  20.4s
# [CV] END estimator__colsample_bytree=0.8783251227163527, estimator__gamma=0.4291794024068599, estimator__learning_rate=0.10778767156056542, estimator__max_depth=6, estimator__min_child_weight=3, estimator__n_estimators=445, estimator__subsample=0.8048372233197124; total time=  19.2s
# [CV] END estimator__colsample_bytree=0.8783251227163527, estimator__gamma=0.4291794024068599, estimator__learning_rate=0.10778767156056542, estimator__max_depth=6, estimator__min_child_weight=3, estimator__n_estimators=445, estimator__subsample=0.8048372233197124; total time=  20.0s
# [CV] END estimator__colsample_bytree=0.8783251227163527, estimator__gamma=0.4291794024068599, estimator__learning_rate=0.10778767156056542, estimator__max_depth=6, estimator__min_child_weight=3, estimator__n_estimators=445, estimator__subsample=0.8048372233197124; total time=  20.1s
# [CV] END estimator__colsample_bytree=0.8783251227163527, estimator__gamma=0.4291794024068599, estimator__learning_rate=0.10778767156056542, estimator__max_depth=6, estimator__min_child_weight=3, estimator__n_estimators=445, estimator__subsample=0.8048372233197124; total time=  20.1s
# [CV] END estimator__colsample_bytree=0.9588863031813307, estimator__gamma=0.4502090285816652, estimator__learning_rate=0.1999304371819804, estimator__max_depth=3, estimator__min_child_weight=1, estimator__n_estimators=198, estimator__subsample=0.8801431319891084; total time=  12.9s
# [CV] END estimator__colsample_bytree=0.9588863031813307, estimator__gamma=0.4502090285816652, estimator__learning_rate=0.1999304371819804, estimator__max_depth=3, estimator__min_child_weight=1, estimator__n_estimators=198, estimator__subsample=0.8801431319891084; total time=  13.0s
# [CV] END estimator__colsample_bytree=0.7364265404201034, estimator__gamma=0.056736760620294535, estimator__learning_rate=0.28740808548356883, estimator__max_depth=8, estimator__min_child_weight=2, estimator__n_estimators=710, estimator__subsample=0.6914200087189198; total time=  39.9s
# [CV] END estimator__colsample_bytree=0.6905983100791752, estimator__gamma=0.32258639520472493, estimator__learning_rate=0.06230992870149743, estimator__max_depth=3, estimator__min_child_weight=2, estimator__n_estimators=971, estimator__subsample=0.6550083776583973; total time=  48.3s
# [CV] END estimator__colsample_bytree=0.6905983100791752, estimator__gamma=0.32258639520472493, estimator__learning_rate=0.06230992870149743, estimator__max_depth=3, estimator__min_child_weight=2, estimator__n_estimators=971, estimator__subsample=0.6550083776583973; total time=  48.2s
# [CV] END estimator__colsample_bytree=0.6905983100791752, estimator__gamma=0.32258639520472493, estimator__learning_rate=0.06230992870149743, estimator__max_depth=3, estimator__min_child_weight=2, estimator__n_estimators=971, estimator__subsample=0.6550083776583973; total time=  51.8s
# [CV] END estimator__colsample_bytree=0.7364265404201034, estimator__gamma=0.056736760620294535, estimator__learning_rate=0.28740808548356883, estimator__max_depth=8, estimator__min_child_weight=2, estimator__n_estimators=710, estimator__subsample=0.6914200087189198; total time=  45.2s
# [CV] END estimator__colsample_bytree=0.7364265404201034, estimator__gamma=0.056736760620294535, estimator__learning_rate=0.28740808548356883, estimator__max_depth=8, estimator__min_child_weight=2, estimator__n_estimators=710, estimator__subsample=0.6914200087189198; total time=  41.9s
# [CV] END estimator__colsample_bytree=0.7364265404201034, estimator__gamma=0.056736760620294535, estimator__learning_rate=0.28740808548356883, estimator__max_depth=8, estimator__min_child_weight=2, estimator__n_estimators=710, estimator__subsample=0.6914200087189198; total time=  41.8s
# [CV] END estimator__colsample_bytree=0.9588863031813307, estimator__gamma=0.4502090285816652, estimator__learning_rate=0.1999304371819804, estimator__max_depth=3, estimator__min_child_weight=1, estimator__n_estimators=198, estimator__subsample=0.8801431319891084; total time=  10.7s
# [CV] END estimator__colsample_bytree=0.7364265404201034, estimator__gamma=0.056736760620294535, estimator__learning_rate=0.28740808548356883, estimator__max_depth=8, estimator__min_child_weight=2, estimator__n_estimators=710, estimator__subsample=0.6914200087189198; total time=  42.3s
# [CV] END estimator__colsample_bytree=0.6699819708383744, estimator__gamma=0.4910841716647178, estimator__learning_rate=0.16499076738130428, estimator__max_depth=3, estimator__min_child_weight=2, estimator__n_estimators=996, estimator__subsample=0.6372411071223597; total time=  40.1s
# [CV] END estimator__colsample_bytree=0.9588863031813307, estimator__gamma=0.4502090285816652, estimator__learning_rate=0.1999304371819804, estimator__max_depth=3, estimator__min_child_weight=1, estimator__n_estimators=198, estimator__subsample=0.8801431319891084; total time=  10.2s
# [CV] END estimator__colsample_bytree=0.9588863031813307, estimator__gamma=0.4502090285816652, estimator__learning_rate=0.1999304371819804, estimator__max_depth=3, estimator__min_child_weight=1, estimator__n_estimators=198, estimator__subsample=0.8801431319891084; total time=  10.2s
# [CV] END estimator__colsample_bytree=0.6905983100791752, estimator__gamma=0.32258639520472493, estimator__learning_rate=0.06230992870149743, estimator__max_depth=3, estimator__min_child_weight=2, estimator__n_estimators=971, estimator__subsample=0.6550083776583973; total time=  52.8s
# [CV] END estimator__colsample_bytree=0.6699819708383744, estimator__gamma=0.4910841716647178, estimator__learning_rate=0.16499076738130428, estimator__max_depth=3, estimator__min_child_weight=2, estimator__n_estimators=996, estimator__subsample=0.6372411071223597; total time=  42.9s
# [CV] END estimator__colsample_bytree=0.6905983100791752, estimator__gamma=0.32258639520472493, estimator__learning_rate=0.06230992870149743, estimator__max_depth=3, estimator__min_child_weight=2, estimator__n_estimators=971, estimator__subsample=0.6550083776583973; total time=  52.4s
# [CV] END estimator__colsample_bytree=0.6699819708383744, estimator__gamma=0.4910841716647178, estimator__learning_rate=0.16499076738130428, estimator__max_depth=3, estimator__min_child_weight=2, estimator__n_estimators=996, estimator__subsample=0.6372411071223597; total time=  43.5s
# ...
# [CV] END estimator__colsample_bytree=0.7572390898667042, estimator__gamma=0.44602327758855664, estimator__learning_rate=0.19934158779917888, estimator__max_depth=4, estimator__min_child_weight=5, estimator__n_estimators=897, estimator__subsample=0.8580413448122259; total time=  32.4s
# [CV] END estimator__colsample_bytree=0.8675696238652398, estimator__gamma=0.43208378253595153, estimator__learning_rate=0.07905558047246658, estimator__max_depth=5, estimator__min_child_weight=4, estimator__n_estimators=646, estimator__subsample=0.9074216057225236; total time=  28.0s
# [CV] END estimator__colsample_bytree=0.8675696238652398, estimator__gamma=0.43208378253595153, estimator__learning_rate=0.07905558047246658, estimator__max_depth=5, estimator__min_child_weight=4, estimator__n_estimators=646, estimator__subsample=0.9074216057225236; total time=  27.9s
# [CV] END estimator__colsample_bytree=0.6174415087017735, estimator__gamma=0.4972752553986705, estimator__learning_rate=0.1509833541972829, estimator__max_depth=8, estimator__min_child_weight=5, estimator__n_estimators=617, estimator__subsample=0.7480634801021777; total time=  25.9s
# [CV] END estimator__colsample_bytree=0.6174415087017735, estimator__gamma=0.4972752553986705, estimator__learning_rate=0.1509833541972829, estimator__max_depth=8, estimator__min_child_weight=5, estimator__n_estimators=617, estimator__subsample=0.7480634801021777; total time=  25.8s
# [CV] END estimator__colsample_bytree=0.8675696238652398, estimator__gamma=0.43208378253595153, estimator__learning_rate=0.07905558047246658, estimator__max_depth=5, estimator__min_child_weight=4, estimator__n_estimators=646, estimator__subsample=0.9074216057225236; total time=  27.8s
# [CV] END estimator__colsample_bytree=0.7572390898667042, estimator__gamma=0.44602327758855664, estimator__learning_rate=0.19934158779917888, estimator__max_depth=4, estimator__min_child_weight=5, estimator__n_estimators=897, estimator__subsample=0.8580413448122259; total time=  32.2s
# [CV] END estimator__colsample_bytree=0.8675696238652398, estimator__gamma=0.43208378253595153, estimator__learning_rate=0.07905558047246658, estimator__max_depth=5, estimator__min_child_weight=4, estimator__n_estimators=646, estimator__subsample=0.9074216057225236; total time=  28.4s
# [CV] END estimator__colsample_bytree=0.6174415087017735, estimator__gamma=0.4972752553986705, estimator__learning_rate=0.1509833541972829, estimator__max_depth=8, estimator__min_child_weight=5, estimator__n_estimators=617, estimator__subsample=0.7480634801021777; total time=  25.8s
# [CV] END estimator__colsample_bytree=0.6174415087017735, estimator__gamma=0.4972752553986705, estimator__learning_rate=0.1509833541972829, estimator__max_depth=8, estimator__min_child_weight=5, estimator__n_estimators=617, estimator__subsample=0.7480634801021777; total time=  25.6s
# [CV] END estimator__colsample_bytree=0.8675696238652398, estimator__gamma=0.43208378253595153, estimator__learning_rate=0.07905558047246658, estimator__max_depth=5, estimator__min_child_weight=4, estimator__n_estimators=646, estimator__subsample=0.9074216057225236; total time=  28.7s
# [CV] END estimator__colsample_bytree=0.7572390898667042, estimator__gamma=0.44602327758855664, estimator__learning_rate=0.19934158779917888, estimator__max_depth=4, estimator__min_child_weight=5, estimator__n_estimators=897, estimator__subsample=0.8580413448122259; total time=  32.6s
# [CV] END estimator__colsample_bytree=0.7572390898667042, estimator__gamma=0.44602327758855664, estimator__learning_rate=0.19934158779917888, estimator__max_depth=4, estimator__min_child_weight=5, estimator__n_estimators=897, estimator__subsample=0.8580413448122259; total time=  34.3s
# [CV] END estimator__colsample_bytree=0.6174415087017735, estimator__gamma=0.4972752553986705, estimator__learning_rate=0.1509833541972829, estimator__max_depth=8, estimator__min_child_weight=5, estimator__n_estimators=617, estimator__subsample=0.7480634801021777; total time=  25.4s
# [CV] END estimator__colsample_bytree=0.606182646611547, estimator__gamma=0.4641592812938627, estimator__learning_rate=0.1384552444951943, estimator__max_depth=7, estimator__min_child_weight=3, estimator__n_estimators=799, estimator__subsample=0.941203782186944; total time=  29.1s
# [CV] END estimator__colsample_bytree=0.606182646611547, estimator__gamma=0.4641592812938627, estimator__learning_rate=0.1384552444951943, estimator__max_depth=7, estimator__min_child_weight=3, estimator__n_estimators=799, estimator__subsample=0.941203782186944; total time=  28.6s
# [CV] END estimator__colsample_bytree=0.606182646611547, estimator__gamma=0.4641592812938627, estimator__learning_rate=0.1384552444951943, estimator__max_depth=7, estimator__min_child_weight=3, estimator__n_estimators=799, estimator__subsample=0.941203782186944; total time=  28.0s
# [CV] END estimator__colsample_bytree=0.606182646611547, estimator__gamma=0.4641592812938627, estimator__learning_rate=0.1384552444951943, estimator__max_depth=7, estimator__min_child_weight=3, estimator__n_estimators=799, estimator__subsample=0.941203782186944; total time=  28.2s
# [CV] END estimator__colsample_bytree=0.606182646611547, estimator__gamma=0.4641592812938627, estimator__learning_rate=0.1384552444951943, estimator__max_depth=7, estimator__min_child_weight=3, estimator__n_estimators=799, estimator__subsample=0.941203782186944; total time=  28.2s
# [CV] END estimator__colsample_bytree=0.7177795568278342, estimator__gamma=0.19254886430096263, estimator__learning_rate=0.26534100145505707, estimator__max_depth=5, estimator__min_child_weight=2, estimator__n_estimators=892, estimator__subsample=0.7578765867237889; total time=  37.8s
# [CV] END estimator__colsample_bytree=0.8073318609454947, estimator__gamma=0.4386865359639777, estimator__learning_rate=0.23223058532626134, estimator__max_depth=3, estimator__min_child_weight=1, estimator__n_estimators=910, estimator__subsample=0.8835643987640474; total time=  33.9s
# [CV] END estimator__colsample_bytree=0.7177795568278342, estimator__gamma=0.19254886430096263, estimator__learning_rate=0.26534100145505707, estimator__max_depth=5, estimator__min_child_weight=2, estimator__n_estimators=892, estimator__subsample=0.7578765867237889; total time=  37.6s
# [CV] END estimator__colsample_bytree=0.7177795568278342, estimator__gamma=0.19254886430096263, estimator__learning_rate=0.26534100145505707, estimator__max_depth=5, estimator__min_child_weight=2, estimator__n_estimators=892, estimator__subsample=0.7578765867237889; total time=  38.0s
# [CV] END estimator__colsample_bytree=0.7177795568278342, estimator__gamma=0.19254886430096263, estimator__learning_rate=0.26534100145505707, estimator__max_depth=5, estimator__min_child_weight=2, estimator__n_estimators=892, estimator__subsample=0.7578765867237889; total time=  37.9s
# [CV] END estimator__colsample_bytree=0.7177795568278342, estimator__gamma=0.19254886430096263, estimator__learning_rate=0.26534100145505707, estimator__max_depth=5, estimator__min_child_weight=2, estimator__n_estimators=892, estimator__subsample=0.7578765867237889; total time=  38.2s
# [CV] END estimator__colsample_bytree=0.8073318609454947, estimator__gamma=0.4386865359639777, estimator__learning_rate=0.23223058532626134, estimator__max_depth=3, estimator__min_child_weight=1, estimator__n_estimators=910, estimator__subsample=0.8835643987640474; total time=  35.1s
# [CV] END estimator__colsample_bytree=0.8073318609454947, estimator__gamma=0.4386865359639777, estimator__learning_rate=0.23223058532626134, estimator__max_depth=3, estimator__min_child_weight=1, estimator__n_estimators=910, estimator__subsample=0.8835643987640474; total time=  34.5s
# [CV] END estimator__colsample_bytree=0.9376852562905246, estimator__gamma=0.46500841740541593, estimator__learning_rate=0.031124839254863167, estimator__max_depth=4, estimator__min_child_weight=6, estimator__n_estimators=762, estimator__subsample=0.6560336060946096; total time=  49.0s
# [CV] END estimator__colsample_bytree=0.9376852562905246, estimator__gamma=0.46500841740541593, estimator__learning_rate=0.031124839254863167, estimator__max_depth=4, estimator__min_child_weight=6, estimator__n_estimators=762, estimator__subsample=0.6560336060946096; total time=  49.5s
# [CV] END estimator__colsample_bytree=0.9376852562905246, estimator__gamma=0.46500841740541593, estimator__learning_rate=0.031124839254863167, estimator__max_depth=4, estimator__min_child_weight=6, estimator__n_estimators=762, estimator__subsample=0.6560336060946096; total time=  49.1s
# [CV] END estimator__colsample_bytree=0.9376852562905246, estimator__gamma=0.46500841740541593, estimator__learning_rate=0.031124839254863167, estimator__max_depth=4, estimator__min_child_weight=6, estimator__n_estimators=762, estimator__subsample=0.6560336060946096; total time=  50.7s
# [CV] END estimator__colsample_bytree=0.8211279907631631, estimator__gamma=0.14825507182389924, estimator__learning_rate=0.13593425693388295, estimator__max_depth=4, estimator__min_child_weight=1, estimator__n_estimators=507, estimator__subsample=0.9652962210225885; total time=  25.1s
# [CV] END estimator__colsample_bytree=0.9376852562905246, estimator__gamma=0.46500841740541593, estimator__learning_rate=0.031124839254863167, estimator__max_depth=4, estimator__min_child_weight=6, estimator__n_estimators=762, estimator__subsample=0.6560336060946096; total time=  50.3s
# [CV] END estimator__colsample_bytree=0.8073318609454947, estimator__gamma=0.4386865359639777, estimator__learning_rate=0.23223058532626134, estimator__max_depth=3, estimator__min_child_weight=1, estimator__n_estimators=910, estimator__subsample=0.8835643987640474; total time=  35.3s
# [CV] END estimator__colsample_bytree=0.8073318609454947, estimator__gamma=0.4386865359639777, estimator__learning_rate=0.23223058532626134, estimator__max_depth=3, estimator__min_child_weight=1, estimator__n_estimators=910, estimator__subsample=0.8835643987640474; total time=  34.6s
# [CV] END estimator__colsample_bytree=0.8211279907631631, estimator__gamma=0.14825507182389924, estimator__learning_rate=0.13593425693388295, estimator__max_depth=4, estimator__min_child_weight=1, estimator__n_estimators=507, estimator__subsample=0.9652962210225885; total time=  25.0s
# [CV] END estimator__colsample_bytree=0.8211279907631631, estimator__gamma=0.14825507182389924, estimator__learning_rate=0.13593425693388295, estimator__max_depth=4, estimator__min_child_weight=1, estimator__n_estimators=507, estimator__subsample=0.9652962210225885; total time=  24.7s
# [CV] END estimator__colsample_bytree=0.8211279907631631, estimator__gamma=0.14825507182389924, estimator__learning_rate=0.13593425693388295, estimator__max_depth=4, estimator__min_child_weight=1, estimator__n_estimators=507, estimator__subsample=0.9652962210225885; total time=  26.0s
# [CV] END estimator__colsample_bytree=0.8211279907631631, estimator__gamma=0.14825507182389924, estimator__learning_rate=0.13593425693388295, estimator__max_depth=4, estimator__min_child_weight=1, estimator__n_estimators=507, estimator__subsample=0.9652962210225885; total time=  25.8s
# [CV] END estimator__colsample_bytree=0.8045369595443751, estimator__gamma=0.2507581473435998, estimator__learning_rate=0.24948855369003253, estimator__max_depth=3, estimator__min_child_weight=6, estimator__n_estimators=499, estimator__subsample=0.6203074124157587; total time=  29.4s
# [CV] END estimator__colsample_bytree=0.8045369595443751, estimator__gamma=0.2507581473435998, estimator__learning_rate=0.24948855369003253, estimator__max_depth=3, estimator__min_child_weight=6, estimator__n_estimators=499, estimator__subsample=0.6203074124157587; total time=  30.2s
# [CV] END estimator__colsample_bytree=0.8045369595443751, estimator__gamma=0.2507581473435998, estimator__learning_rate=0.24948855369003253, estimator__max_depth=3, estimator__min_child_weight=6, estimator__n_estimators=499, estimator__subsample=0.6203074124157587; total time=  28.2s
# [CV] END estimator__colsample_bytree=0.954646859580264, estimator__gamma=0.013808385936852352, estimator__learning_rate=0.18365946865226762, estimator__max_depth=9, estimator__min_child_weight=6, estimator__n_estimators=150, estimator__subsample=0.786239207252984; total time=  23.1s
# [CV] END estimator__colsample_bytree=0.954646859580264, estimator__gamma=0.013808385936852352, estimator__learning_rate=0.18365946865226762, estimator__max_depth=9, estimator__min_child_weight=6, estimator__n_estimators=150, estimator__subsample=0.786239207252984; total time=  23.5s
# [CV] END estimator__colsample_bytree=0.954646859580264, estimator__gamma=0.013808385936852352, estimator__learning_rate=0.18365946865226762, estimator__max_depth=9, estimator__min_child_weight=6, estimator__n_estimators=150, estimator__subsample=0.786239207252984; total time=  22.6s
# [CV] END estimator__colsample_bytree=0.954646859580264, estimator__gamma=0.013808385936852352, estimator__learning_rate=0.18365946865226762, estimator__max_depth=9, estimator__min_child_weight=6, estimator__n_estimators=150, estimator__subsample=0.786239207252984; total time=  23.4s
# [CV] END estimator__colsample_bytree=0.8045369595443751, estimator__gamma=0.2507581473435998, estimator__learning_rate=0.24948855369003253, estimator__max_depth=3, estimator__min_child_weight=6, estimator__n_estimators=499, estimator__subsample=0.6203074124157587; total time=  27.1s
# [CV] END estimator__colsample_bytree=0.954646859580264, estimator__gamma=0.013808385936852352, estimator__learning_rate=0.18365946865226762, estimator__max_depth=9, estimator__min_child_weight=6, estimator__n_estimators=150, estimator__subsample=0.786239207252984; total time=  22.2s
# [CV] END estimator__colsample_bytree=0.8045369595443751, estimator__gamma=0.2507581473435998, estimator__learning_rate=0.24948855369003253, estimator__max_depth=3, estimator__min_child_weight=6, estimator__n_estimators=499, estimator__subsample=0.6203074124157587; total time=  25.5s
# [CV] END estimator__colsample_bytree=0.8170578538830306, estimator__gamma=0.1432706260641422, estimator__learning_rate=0.18724997817070324, estimator__max_depth=8, estimator__min_child_weight=1, estimator__n_estimators=791, estimator__subsample=0.6155338937717693; total time=  24.5s
# [CV] END estimator__colsample_bytree=0.8170578538830306, estimator__gamma=0.1432706260641422, estimator__learning_rate=0.18724997817070324, estimator__max_depth=8, estimator__min_child_weight=1, estimator__n_estimators=791, estimator__subsample=0.6155338937717693; total time=  22.7s
# [CV] END estimator__colsample_bytree=0.8170578538830306, estimator__gamma=0.1432706260641422, estimator__learning_rate=0.18724997817070324, estimator__max_depth=8, estimator__min_child_weight=1, estimator__n_estimators=791, estimator__subsample=0.6155338937717693; total time=  23.9s
# [CV] END estimator__colsample_bytree=0.8170578538830306, estimator__gamma=0.1432706260641422, estimator__learning_rate=0.18724997817070324, estimator__max_depth=8, estimator__min_child_weight=1, estimator__n_estimators=791, estimator__subsample=0.6155338937717693; total time=  23.6s
# [CV] END estimator__colsample_bytree=0.8170578538830306, estimator__gamma=0.1432706260641422, estimator__learning_rate=0.18724997817070324, estimator__max_depth=8, estimator__min_child_weight=1, estimator__n_estimators=791, estimator__subsample=0.6155338937717693; total time=  22.2s
#
# Best parameters found:
# {'estimator__colsample_bytree': np.float64(0.954646859580264), 'estimator__gamma': np.float64(0.013808385936852352), 'estimator__learning_rate': np.float64(0.18365946865226762), 'estimator__max_depth': 9, 'estimator__min_child_weight': 6, 'estimator__n_estimators': 150, 'estimator__subsample': np.float64(0.786239207252984)}
#
# Best score:
# -0.010133048207014394

# %%
#Create the final model with best parameters
best_params = {k.replace('estimator__', ''): v 
               for k, v in random_search.best_params_.items()}

# Run the cross-validation with the optimized model
best_model = XGBRegressor(**best_params, objective="reg:squarederror")
multi_target_best = MultiOutputRegressor(best_model)

# Use the same stratified k-fold approach as before
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
y_binned = pd.qcut(y['CTR_encoded'], q=5, labels=False, duplicates='drop')

mse_scores_ctr = []
mse_scores_cpm = []
r2_scores_ctr = []
r2_scores_cpm = []

# Cross-validation with optimized parameters
for fold_num, (train_index, test_index) in enumerate(skf.split(X, y_binned)):
    print(f"Fold {fold_num + 1}")
    
    X_train_fold = X.iloc[train_index]
    X_test_fold = X.iloc[test_index]
    y_train_fold = y.iloc[train_index]
    y_test_fold = y.iloc[test_index]

    # Train with optimized parameters
    multi_target_best.fit(X_train_fold, y_train_fold)
    y_pred = multi_target_best.predict(X_test_fold)

    # Calculate metrics
    mse_ctr = mean_squared_error(y_test_fold['CTR_encoded'], y_pred[:, 0])
    mse_cpm = mean_squared_error(y_test_fold['AverageWinPrice (CPM)_encoded'], y_pred[:, 1])
    mse_scores_ctr.append(mse_ctr)
    mse_scores_cpm.append(mse_cpm)
    
    r2_ctr = r2_score(y_test_fold['CTR_encoded'], y_pred[:, 0])
    r2_cpm = r2_score(y_test_fold['AverageWinPrice (CPM)_encoded'], y_pred[:, 1])
    r2_scores_ctr.append(r2_ctr)
    r2_scores_cpm.append(r2_cpm)

    print(f"Training size: {len(X_train_fold)}, Validation size: {len(X_test_fold)}")

# Print final results
print("\nFinal Cross-Validation Scores with Optimized Parameters:")
print(f"Average MSE for CTR: {np.mean(mse_scores_ctr):.4f}")
print(f"Average R2 for CTR: {np.mean(r2_scores_ctr):.4f}")
print(f"Average MSE for CPM: {np.mean(mse_scores_cpm):.4f}")
print(f"Average R2 for CPM: {np.mean(r2_scores_cpm):.4f}")

# Compare with previous results
print("\nImprovement from base model:\n")
# Add your previous metrics here for comparison
print("Average MSE for CTR: 0.0043")
print("Average R2 for CTR: 0.1126")
print()
print("Average MSE for CPM: 0.0331") 
print("Average R2 for CPM: 0.6998")
# Out:
# Fold 1
# Training size: 243693, Validation size: 60924
# Fold 2
# Training size: 243693, Validation size: 60924
# Fold 3
# Training size: 243694, Validation size: 60923
# Fold 4
# Training size: 243694, Validation size: 60923
# Fold 5
# Training size: 243694, Validation size: 60923
#
# Final Cross-Validation Scores with Optimized Parameters:
# Average MSE for CTR: 0.0037
# Average R2 for CTR: 0.2394
# Average MSE for CPM: 0.0167
# Average R2 for CPM: 0.8483
#
# Improvement from base model:
#
# Average MSE for CTR: 0.0043
# Average R2 for CTR: 0.1126
#
# Average MSE for CPM: 0.0331
# Average R2 for CPM: 0.6998
